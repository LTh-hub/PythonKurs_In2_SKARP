# %%
# Med inspiration från YouTube video tutorial
# Classificering av hundar och Katter från bilder 
# An updated deep learning introduction using Python, TensorFlow, and Keras
# 
#

# %%
import numpy as np                   # för array matrix operationer
import matplotlib.pyplot as plt      # för att visualisera data
import os                            # för att iterera genom bibliotek med bilder

#pip install opencv-python
import cv2                           # för att uföra image operationer



#pip install --upgrade tensorflow
#import tensorflow as tf
#tf.__version__


#os.path


IMG_SIZE = 75

#DATADIR = pwd
#DATADIR = "C:\\Users\\larth\\PythUtb\\InlUppg_2\\prep\\VideoTutorial_Cat_Dog\\"
DATADIR = "C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\"                                      # path till katalog med djurbilder
#DATADIR_MOD = DATADIR + "pyth_mod_learn\\"                                         # path till sparad modell
DATADIR_MOD = DATADIR                                         # path till sparad modell

#CATEGORIES = ["500pCats", "500pDogs"]
CATEGORIES = ["CatTrain", "DogTrain"]
#CATEGORIES = ["Cat", "Dog"]

# Ska titta på ett första foto
for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)      # Väljer att endast hantera gråskalebilder
        print(f"{path = }")
        print(f"{category = }")
        print(f"{img = }")
        print(img_array)
        plt.imshow(img_array, cmap="grey")
        plt.show()
        #pause
        break
    break      # För att stanna vid 1:a fotot
# Out:
# path = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\CatTrain'
# category = 'CatTrain'
# img = '1.jpeg'
# [[ 96  71  67 ... 198 199 200]
#  [ 83  67  69 ... 195 196 197]
#  [ 61  58  68 ... 192 193 194]
#  ...
#  [ 85  70  73 ...  79  91  95]
#  [ 85  73  70 ...  70  80  92]
#  [ 85  74  70 ...  72  83  96]]

# %%
# IMG_SIZE = 150
new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap="grey")
plt.show()

# %%
## IMG_SIZE = 150
#new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
#plt.imshow(new_array, cmap="grey")
#plt.show()

# %%
# Grundläggande kontroll på bildstorlek vad gäller pxl-antal, storlek och formfaktor
# Vilken upplösning (pxl) har bilderna i aktuella kataloger
# För att formatet på bilderna inte ska sänka metoden

vecRC = []   # vector med antal Rader & Columner
to_small_pic = 0

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)  # path till katter och hundar
    for img in os.listdir(path):
        try:
            img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
            #print(f"{img_array.shape = }       {img_array.size = }       {len(img_array) = }  ")
            if img_array[0,0]<(IMG_SIZE+1):
                to_small_pic += 1
                print(f"{img_array[0,0] = }")
            elif img_array[0,1]<(IMG_SIZE+1):
                to_small_pic += 1
                print(f"{img_array[0,1] = }")
            else:
                vecRC.append(img_array.shape)
        except Exceptin as e:
            print(e)
            print(path)
            
        #break
    #break
    

vecRC = np.array(vecRC)  # behöver np-formatet på vectorn för att enkelt få fram innehåll

print(f"{vecRC.shape = }       {vecRC.size = }       {len(vecRC) = }       {len(vecRC[:,0]) = }       {len(vecRC[:,1]) = }  ")
print(f"Number of pictures that was too small: {to_small_pic}")
# Out:
# img_array[0,0] = 96
# img_array[0,0] = 5
# img_array[0,0] = 9
# img_array[0,0] = 34
# img_array[0,0] = 90
# img_array[0,0] = 63
# img_array[0,0] = 52
# img_array[0,0] = 81
# img_array[0,0] = 2
# img_array[0,0] = 55
# img_array[0,0] = 56
# img_array[0,1] = 100
# img_array[0,0] = 15
# img_array[0,0] = 32
# img_array[0,0] = 12
# img_array[0,1] = 94
# img_array[0,0] = 33
# img_array[0,0] = 13
# img_array[0,0] = 80
# img_array[0,0] = 4
# img_array[0,0] = 9
# img_array[0,0] = 40
# img_array[0,0] = 46
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 59
# img_array[0,1] = 93
# img_array[0,0] = 51
# img_array[0,0] = 71
# img_array[0,0] = 35
# img_array[0,0] = 82
# img_array[0,0] = 84
# img_array[0,0] = 48
# img_array[0,0] = 73
# img_array[0,0] = 13
# img_array[0,0] = 80
# img_array[0,0] = 34
# img_array[0,0] = 89
# img_array[0,0] = 53
# img_array[0,0] = 73
# img_array[0,0] = 1
# img_array[0,0] = 0
# img_array[0,0] = 9
# img_array[0,0] = 5
# img_array[0,0] = 18
# img_array[0,0] = 78
# img_array[0,0] = 18
# img_array[0,0] = 7
# img_array[0,0] = 12
# img_array[0,0] = 1
# img_array[0,0] = 11
# img_array[0,0] = 29
# img_array[0,0] = 89
# img_array[0,0] = 23
# img_array[0,0] = 25
# img_array[0,0] = 77
# img_array[0,0] = 23
# img_array[0,0] = 68
# img_array[0,0] = 1
# img_array[0,0] = 88
# img_array[0,0] = 99
# img_array[0,0] = 59
# img_array[0,0] = 58
# img_array[0,0] = 38
# img_array[0,0] = 18
# img_array[0,0] = 98
# img_array[0,0] = 9
# img_array[0,0] = 7
# img_array[0,0] = 18
# img_array[0,0] = 57
# img_array[0,0] = 45
# img_array[0,0] = 76
# img_array[0,0] = 1
# img_array[0,1] = 92
# img_array[0,0] = 27
# img_array[0,0] = 79
# img_array[0,0] = 0
# img_array[0,0] = 49
# img_array[0,0] = 25
# img_array[0,0] = 63
# img_array[0,0] = 34
# img_array[0,0] = 20
# img_array[0,0] = 65
# img_array[0,1] = 70
# img_array[0,0] = 6
# img_array[0,0] = 23
# img_array[0,0] = 34
# img_array[0,0] = 92
# img_array[0,0] = 34
# img_array[0,0] = 35
# img_array[0,0] = 3
# img_array[0,0] = 30
# img_array[0,0] = 85
# img_array[0,0] = 78
# img_array[0,0] = 84
# img_array[0,0] = 1
# img_array[0,0] = 0
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 2
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 41
# img_array[0,0] = 85
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 18
# img_array[0,0] = 1
# img_array[0,0] = 3
# img_array[0,0] = 1
# img_array[0,0] = 52
# img_array[0,0] = 90
# img_array[0,0] = 5
# img_array[0,0] = 0
# img_array[0,0] = 44
# img_array[0,0] = 50
# img_array[0,0] = 79
# img_array[0,0] = 84
# img_array[0,0] = 72
# img_array[0,0] = 63
# img_array[0,0] = 91
# img_array[0,0] = 97
# img_array[0,0] = 99
# img_array[0,0] = 84
# img_array[0,0] = 24
# img_array[0,0] = 11
# img_array[0,0] = 82
# img_array[0,0] = 62
# img_array[0,0] = 13
# img_array[0,0] = 52
# img_array[0,0] = 96
# img_array[0,0] = 7
# img_array[0,0] = 1
# img_array[0,0] = 58
# img_array[0,0] = 8
# img_array[0,0] = 44
# img_array[0,0] = 31
# img_array[0,0] = 86
# img_array[0,0] = 62
# img_array[0,0] = 24
# img_array[0,0] = 39
# img_array[0,0] = 14
# img_array[0,0] = 77
# img_array[0,0] = 58
# img_array[0,0] = 96
# img_array[0,0] = 1
# img_array[0,0] = 52
# img_array[0,0] = 3
# img_array[0,0] = 18
# img_array[0,0] = 31
# img_array[0,0] = 21
# img_array[0,0] = 95
# img_array[0,0] = 43
# img_array[0,0] = 1
# img_array[0,0] = 80
# img_array[0,0] = 46
# img_array[0,0] = 70
# img_array[0,0] = 81
# img_array[0,0] = 51
# img_array[0,1] = 98
# img_array[0,1] = 93
# img_array[0,0] = 23
# img_array[0,0] = 49
# img_array[0,0] = 77
# img_array[0,0] = 50
# img_array[0,0] = 80
# img_array[0,0] = 97
# img_array[0,0] = 22
# img_array[0,0] = 2
# img_array[0,0] = 88
# img_array[0,0] = 44
# img_array[0,0] = 93
# img_array[0,0] = 31
# img_array[0,0] = 73
# img_array[0,0] = 55
# img_array[0,0] = 47
# img_array[0,0] = 68
# img_array[0,0] = 1
# img_array[0,0] = 0
# img_array[0,0] = 34
# img_array[0,0] = 54
# img_array[0,0] = 96
# img_array[0,0] = 37
# img_array[0,0] = 59
# img_array[0,0] = 1
# img_array[0,0] = 64
# img_array[0,0] = 84
# img_array[0,0] = 41
# img_array[0,0] = 6
# img_array[0,0] = 51
# img_array[0,0] = 1
# img_array[0,0] = 77
# img_array[0,0] = 40
# img_array[0,0] = 19
# img_array[0,0] = 80
# img_array[0,0] = 63
# img_array[0,0] = 1
# img_array[0,0] = 21
# img_array[0,0] = 4
# img_array[0,0] = 1
# img_array[0,0] = 39
# img_array[0,0] = 52
# img_array[0,0] = 1
# img_array[0,0] = 85
# img_array[0,0] = 4
# img_array[0,0] = 73
# img_array[0,0] = 37
# img_array[0,1] = 100
# img_array[0,1] = 100
# img_array[0,0] = 66
# img_array[0,0] = 73
# img_array[0,0] = 59
# img_array[0,0] = 34
# img_array[0,0] = 3
# img_array[0,0] = 13
# img_array[0,0] = 97
# img_array[0,0] = 14
# img_array[0,0] = 33
# img_array[0,0] = 55
# img_array[0,0] = 14
# img_array[0,0] = 30
# img_array[0,0] = 13
# img_array[0,0] = 12
# img_array[0,0] = 23
# img_array[0,0] = 32
# img_array[0,0] = 52
# img_array[0,0] = 76
# img_array[0,0] = 35
# img_array[0,0] = 2
# img_array[0,1] = 89
# img_array[0,0] = 87
# img_array[0,0] = 2
# img_array[0,0] = 89
# img_array[0,0] = 8
# img_array[0,0] = 23
# img_array[0,0] = 46
# img_array[0,0] = 30
# img_array[0,0] = 41
# img_array[0,0] = 53
# img_array[0,0] = 57
# img_array[0,0] = 22
# img_array[0,0] = 47
# img_array[0,0] = 96
# img_array[0,0] = 74
# img_array[0,0] = 94
# img_array[0,0] = 1
# img_array[0,0] = 97
# img_array[0,0] = 0
# img_array[0,0] = 1
# img_array[0,0] = 44
# img_array[0,1] = 93
# img_array[0,0] = 4
# img_array[0,0] = 39
# img_array[0,0] = 20
# img_array[0,0] = 52
# img_array[0,0] = 0
# img_array[0,0] = 43
# img_array[0,0] = 61
# img_array[0,0] = 97
# img_array[0,0] = 21
# img_array[0,0] = 70
# img_array[0,0] = 32
# img_array[0,0] = 33
# img_array[0,0] = 17
# img_array[0,0] = 48
# img_array[0,0] = 32
# img_array[0,0] = 53
# img_array[0,0] = 52
# img_array[0,0] = 1
# img_array[0,0] = 49
# img_array[0,0] = 93
# img_array[0,0] = 32
# img_array[0,0] = 1
# img_array[0,0] = 12
# img_array[0,0] = 6
# img_array[0,0] = 0
# img_array[0,0] = 63
# img_array[0,0] = 76
# img_array[0,0] = 14
# img_array[0,0] = 54
# img_array[0,0] = 4
# img_array[0,0] = 46
# img_array[0,0] = 74
# img_array[0,0] = 15
# img_array[0,0] = 76
# img_array[0,0] = 51
# img_array[0,0] = 39
# img_array[0,0] = 6
# img_array[0,0] = 23
# img_array[0,0] = 18
# img_array[0,0] = 12
# img_array[0,0] = 57
# img_array[0,0] = 80
# img_array[0,0] = 69
# img_array[0,0] = 39
# img_array[0,0] = 30
# img_array[0,0] = 19
# img_array[0,0] = 65
# img_array[0,0] = 38
# img_array[0,0] = 52
# img_array[0,0] = 14
# img_array[0,0] = 24
# img_array[0,0] = 32
# img_array[0,0] = 72
# img_array[0,0] = 54
# img_array[0,0] = 78
# img_array[0,0] = 19
# img_array[0,0] = 7
# img_array[0,0] = 1
# img_array[0,0] = 48
# img_array[0,0] = 3
# img_array[0,0] = 38
# img_array[0,0] = 39
# img_array[0,0] = 48
# img_array[0,0] = 2
# img_array[0,0] = 55
# img_array[0,0] = 61
# img_array[0,0] = 53
# img_array[0,0] = 26
# img_array[0,0] = 53
# img_array[0,0] = 89
# img_array[0,0] = 8
# img_array[0,0] = 6
# img_array[0,0] = 29
# img_array[0,0] = 61
# img_array[0,0] = 39
# img_array[0,0] = 74
# img_array[0,0] = 47
# img_array[0,0] = 1
# img_array[0,0] = 15
# img_array[0,0] = 20
# img_array[0,0] = 71
# img_array[0,0] = 32
# img_array[0,0] = 63
# img_array[0,0] = 26
# img_array[0,0] = 35
# img_array[0,0] = 61
# img_array[0,0] = 1
# img_array[0,0] = 8
# img_array[0,0] = 61
# img_array[0,0] = 95
# img_array[0,0] = 12
# img_array[0,0] = 52
# img_array[0,0] = 47
# img_array[0,0] = 55
# img_array[0,0] = 55
# img_array[0,0] = 15
# img_array[0,0] = 3
# img_array[0,0] = 60
# img_array[0,0] = 19
# img_array[0,0] = 0
# img_array[0,0] = 25
# img_array[0,0] = 1
# img_array[0,0] = 54
# img_array[0,0] = 63
# img_array[0,0] = 70
# img_array[0,0] = 11
# img_array[0,0] = 100
# img_array[0,0] = 17
# img_array[0,0] = 51
# img_array[0,0] = 45
# img_array[0,0] = 35
# img_array[0,0] = 12
# img_array[0,0] = 6
# img_array[0,0] = 18
# img_array[0,0] = 37
# img_array[0,0] = 87
# img_array[0,0] = 33
# img_array[0,0] = 2
# img_array[0,0] = 49
# img_array[0,0] = 39
# img_array[0,0] = 22
# img_array[0,0] = 65
# img_array[0,0] = 35
# img_array[0,0] = 58
# img_array[0,0] = 51
# img_array[0,0] = 70
# img_array[0,0] = 71
# img_array[0,0] = 65
# img_array[0,0] = 73
# img_array[0,0] = 71
# img_array[0,0] = 75
# img_array[0,1] = 100
# img_array[0,0] = 55
# img_array[0,0] = 64
# img_array[0,0] = 80
# img_array[0,0] = 57
# img_array[0,0] = 40
# img_array[0,0] = 15
# img_array[0,0] = 28
# img_array[0,0] = 95
# img_array[0,0] = 42
# img_array[0,0] = 29
# img_array[0,0] = 66
# img_array[0,0] = 44
# img_array[0,0] = 55
# img_array[0,0] = 1
# img_array[0,0] = 79
# img_array[0,0] = 62
# img_array[0,0] = 16
# img_array[0,0] = 15
# img_array[0,0] = 91
# img_array[0,0] = 75
# img_array[0,0] = 81
# img_array[0,0] = 1
# img_array[0,0] = 10
# img_array[0,0] = 97
# img_array[0,0] = 38
# img_array[0,0] = 44
# img_array[0,0] = 53
# img_array[0,0] = 25
# img_array[0,0] = 19
# img_array[0,0] = 49
# img_array[0,0] = 1
# img_array[0,0] = 41
# img_array[0,0] = 2
# img_array[0,0] = 31
# img_array[0,0] = 15
# img_array[0,0] = 8
# img_array[0,0] = 97
# img_array[0,0] = 67
# img_array[0,0] = 84
# img_array[0,0] = 84
# img_array[0,0] = 90
# img_array[0,0] = 1
# img_array[0,0] = 60
# img_array[0,0] = 9
# img_array[0,0] = 50
# img_array[0,0] = 18
# img_array[0,0] = 13
# img_array[0,0] = 2
# img_array[0,0] = 22
# img_array[0,1] = 82
# img_array[0,1] = 98
# img_array[0,0] = 20
# img_array[0,0] = 81
# img_array[0,0] = 1
# img_array[0,0] = 73
# img_array[0,0] = 39
# img_array[0,0] = 78
# img_array[0,0] = 25
# img_array[0,0] = 100
# img_array[0,0] = 31
# img_array[0,0] = 95
# img_array[0,0] = 53
# img_array[0,0] = 25
# img_array[0,0] = 30
# img_array[0,0] = 14
# img_array[0,0] = 32
# img_array[0,1] = 74
# img_array[0,0] = 35
# img_array[0,0] = 12
# img_array[0,0] = 74
# img_array[0,0] = 74
# img_array[0,0] = 56
# img_array[0,0] = 9
# img_array[0,0] = 52
# img_array[0,0] = 8
# img_array[0,0] = 14
# img_array[0,0] = 36
# img_array[0,0] = 76
# img_array[0,0] = 15
# img_array[0,0] = 55
# img_array[0,0] = 83
# img_array[0,0] = 98
# img_array[0,0] = 52
# img_array[0,0] = 69
# img_array[0,0] = 1
# img_array[0,0] = 0
# img_array[0,0] = 25
# img_array[0,0] = 17
# img_array[0,0] = 13
# img_array[0,0] = 55
# img_array[0,0] = 99
# img_array[0,0] = 61
# img_array[0,0] = 35
# img_array[0,0] = 55
# img_array[0,0] = 98
# img_array[0,0] = 10
# img_array[0,0] = 70
# img_array[0,0] = 96
# img_array[0,0] = 28
# img_array[0,0] = 46
# img_array[0,0] = 9
# img_array[0,0] = 73
# img_array[0,0] = 45
# img_array[0,0] = 52
# img_array[0,0] = 25
# img_array[0,0] = 54
# img_array[0,0] = 17
# img_array[0,0] = 16
# img_array[0,0] = 11
# img_array[0,0] = 4
# img_array[0,0] = 93
# img_array[0,0] = 26
# img_array[0,0] = 16
# img_array[0,0] = 77
# img_array[0,0] = 53
# img_array[0,0] = 22
# img_array[0,0] = 42
# img_array[0,0] = 34
# img_array[0,0] = 99
# img_array[0,0] = 88
# img_array[0,0] = 20
# img_array[0,0] = 100
# img_array[0,0] = 91
# img_array[0,0] = 78
# img_array[0,0] = 85
# img_array[0,0] = 86
# img_array[0,0] = 11
# img_array[0,0] = 36
# img_array[0,0] = 78
# img_array[0,0] = 88
# img_array[0,0] = 35
# img_array[0,0] = 32
# img_array[0,0] = 40
# img_array[0,0] = 22
# img_array[0,0] = 76
# img_array[0,0] = 26
# img_array[0,0] = 50
# img_array[0,0] = 34
# img_array[0,0] = 78
# img_array[0,0] = 25
# img_array[0,0] = 92
# img_array[0,0] = 84
# img_array[0,0] = 71
# img_array[0,0] = 65
# img_array[0,0] = 29
# img_array[0,0] = 4
# img_array[0,0] = 69
# img_array[0,0] = 93
# img_array[0,0] = 14
# img_array[0,0] = 48
# img_array[0,0] = 34
# img_array[0,0] = 55
# img_array[0,0] = 87
# img_array[0,0] = 44
# img_array[0,0] = 76
# img_array[0,0] = 14
# img_array[0,0] = 86
# img_array[0,0] = 21
# img_array[0,0] = 87
# img_array[0,0] = 60
# img_array[0,0] = 51
# img_array[0,1] = 77
# img_array[0,0] = 33
# img_array[0,0] = 82
# img_array[0,0] = 78
# img_array[0,0] = 45
# img_array[0,0] = 51
# img_array[0,0] = 41
# img_array[0,0] = 57
# img_array[0,0] = 95
# img_array[0,0] = 89
# img_array[0,0] = 15
# img_array[0,0] = 41
# img_array[0,0] = 68
# img_array[0,0] = 81
# img_array[0,0] = 41
# img_array[0,0] = 31
# img_array[0,0] = 37
# img_array[0,0] = 82
# img_array[0,0] = 79
# img_array[0,0] = 51
# img_array[0,0] = 55
# img_array[0,0] = 74
# img_array[0,0] = 22
# img_array[0,0] = 26
# img_array[0,0] = 64
# img_array[0,0] = 13
# img_array[0,0] = 11
# img_array[0,0] = 23
# img_array[0,0] = 76
# img_array[0,0] = 10
# img_array[0,0] = 85
# img_array[0,0] = 19
# img_array[0,0] = 95
# img_array[0,0] = 46
# img_array[0,0] = 37
# img_array[0,0] = 84
# img_array[0,0] = 2
# img_array[0,0] = 26
# img_array[0,0] = 28
# img_array[0,0] = 64
# img_array[0,0] = 0
# img_array[0,0] = 15
# img_array[0,0] = 6
# img_array[0,0] = 85
# img_array[0,0] = 86
# img_array[0,0] = 7
# img_array[0,0] = 93
# img_array[0,0] = 91
# img_array[0,0] = 78
# img_array[0,0] = 44
# img_array[0,0] = 5
# img_array[0,0] = 78
# img_array[0,0] = 69
# img_array[0,0] = 66
# img_array[0,0] = 81
# img_array[0,0] = 1
# img_array[0,0] = 69
# img_array[0,0] = 75
# img_array[0,0] = 12
# img_array[0,0] = 96
# img_array[0,0] = 62
# img_array[0,0] = 20
# img_array[0,0] = 48
# img_array[0,0] = 67
# img_array[0,0] = 50
# img_array[0,0] = 95
# img_array[0,0] = 66
# img_array[0,0] = 71
# img_array[0,0] = 19
# img_array[0,0] = 7
# img_array[0,0] = 21
# img_array[0,0] = 95
# img_array[0,0] = 14
# img_array[0,0] = 53
# img_array[0,0] = 94
# img_array[0,0] = 75
# img_array[0,0] = 13
# img_array[0,0] = 84
# img_array[0,0] = 35
# img_array[0,0] = 7
# img_array[0,0] = 29
# img_array[0,0] = 8
# img_array[0,0] = 11
# img_array[0,0] = 10
# img_array[0,0] = 82
# img_array[0,0] = 59
# img_array[0,0] = 16
# img_array[0,0] = 60
# img_array[0,0] = 34
# img_array[0,0] = 37
# img_array[0,0] = 56
# img_array[0,0] = 57
# img_array[0,0] = 97
# img_array[0,0] = 88
# img_array[0,0] = 82
# img_array[0,0] = 72
# img_array[0,0] = 83
# img_array[0,0] = 41
# img_array[0,0] = 57
# img_array[0,0] = 2
# img_array[0,0] = 62
# img_array[0,0] = 69
# img_array[0,0] = 19
# img_array[0,0] = 25
# img_array[0,0] = 42
# img_array[0,0] = 7
# img_array[0,0] = 26
# img_array[0,0] = 82
# img_array[0,0] = 36
# img_array[0,0] = 37
# img_array[0,0] = 16
# img_array[0,0] = 16
# img_array[0,0] = 20
# img_array[0,0] = 95
# img_array[0,0] = 35
# img_array[0,0] = 77
# img_array[0,0] = 29
# img_array[0,0] = 78
# img_array[0,0] = 30
# img_array[0,0] = 25
# img_array[0,0] = 86
# img_array[0,0] = 24
# img_array[0,0] = 16
# img_array[0,0] = 55
# img_array[0,0] = 30
# img_array[0,0] = 98
# img_array[0,0] = 29
# img_array[0,0] = 40
# img_array[0,0] = 79
# img_array[0,0] = 75
# img_array[0,0] = 77
# img_array[0,0] = 56
# img_array[0,0] = 0
# img_array[0,0] = 88
# img_array[0,0] = 88
# img_array[0,0] = 92
# img_array[0,0] = 10
# img_array[0,0] = 31
# img_array[0,0] = 84
# img_array[0,0] = 10
# img_array[0,0] = 67
# img_array[0,0] = 79
# img_array[0,0] = 29
# img_array[0,0] = 0
# img_array[0,0] = 6
# img_array[0,0] = 27
# img_array[0,0] = 0
# img_array[0,0] = 28
# img_array[0,0] = 29
# img_array[0,0] = 42
# img_array[0,0] = 53
# img_array[0,0] = 76
# img_array[0,0] = 18
# img_array[0,0] = 1
# img_array[0,0] = 72
# img_array[0,0] = 57
# img_array[0,0] = 37
# img_array[0,0] = 26
# img_array[0,0] = 47
# img_array[0,0] = 20
# img_array[0,0] = 67
# img_array[0,0] = 74
# img_array[0,0] = 53
# img_array[0,0] = 19
# img_array[0,0] = 20
# img_array[0,0] = 33
# img_array[0,0] = 55
# img_array[0,0] = 90
# img_array[0,0] = 77
# img_array[0,0] = 52
# img_array[0,0] = 40
# img_array[0,0] = 47
# img_array[0,0] = 84
# img_array[0,1] = 83
# img_array[0,0] = 23
# img_array[0,0] = 31
# img_array[0,0] = 39
# img_array[0,0] = 83
# img_array[0,0] = 75
# img_array[0,0] = 86
# img_array[0,0] = 75
# img_array[0,0] = 38
# img_array[0,0] = 12
# img_array[0,0] = 72
# img_array[0,0] = 25
# img_array[0,0] = 83
# img_array[0,0] = 2
# img_array[0,0] = 6
# img_array[0,0] = 71
# img_array[0,0] = 61
# img_array[0,0] = 37
# img_array[0,0] = 99
# img_array[0,0] = 82
# img_array[0,0] = 92
# img_array[0,0] = 67
# img_array[0,0] = 96
# img_array[0,0] = 37
# img_array[0,0] = 85
# img_array[0,0] = 68
# img_array[0,0] = 10
# img_array[0,0] = 39
# img_array[0,0] = 90
# img_array[0,0] = 25
# img_array[0,1] = 91
# img_array[0,0] = 47
# img_array[0,0] = 29
# img_array[0,0] = 12
# img_array[0,0] = 92
# img_array[0,0] = 100
# img_array[0,0] = 99
# img_array[0,0] = 0
# img_array[0,0] = 64
# img_array[0,0] = 69
# img_array[0,0] = 29
# img_array[0,0] = 55
# img_array[0,0] = 26
# img_array[0,0] = 2
# img_array[0,0] = 96
# img_array[0,0] = 22
# img_array[0,0] = 74
# img_array[0,0] = 66
# img_array[0,0] = 9
# img_array[0,0] = 24
# img_array[0,0] = 13
# img_array[0,0] = 32
# img_array[0,0] = 51
# img_array[0,0] = 11
# img_array[0,0] = 80
# img_array[0,0] = 48
# img_array[0,0] = 91
# img_array[0,0] = 23
# img_array[0,0] = 3
# img_array[0,0] = 17
# img_array[0,0] = 48
# img_array[0,0] = 72
# img_array[0,0] = 16
# img_array[0,0] = 26
# img_array[0,0] = 57
# img_array[0,1] = 100
# img_array[0,0] = 87
# img_array[0,0] = 9
# img_array[0,0] = 32
# img_array[0,0] = 27
# img_array[0,0] = 58
# img_array[0,0] = 47
# img_array[0,0] = 70
# img_array[0,0] = 7
# img_array[0,0] = 3
# img_array[0,0] = 15
# img_array[0,0] = 83
# img_array[0,1] = 29
# img_array[0,0] = 19
# img_array[0,0] = 68
# img_array[0,0] = 44
# img_array[0,0] = 29
# img_array[0,0] = 17
# img_array[0,0] = 87
# img_array[0,0] = 94
# img_array[0,0] = 14
# img_array[0,0] = 62
# img_array[0,0] = 78
# img_array[0,0] = 22
# img_array[0,0] = 1
# img_array[0,0] = 98
# img_array[0,1] = 96
# img_array[0,0] = 69
# img_array[0,0] = 50
# img_array[0,0] = 92
# img_array[0,0] = 88
# img_array[0,0] = 95
# img_array[0,0] = 39
# img_array[0,1] = 98
# img_array[0,0] = 42
# img_array[0,0] = 66
# img_array[0,0] = 37
# img_array[0,0] = 77
# img_array[0,0] = 29
# img_array[0,0] = 92
# img_array[0,0] = 50
# img_array[0,0] = 61
# img_array[0,0] = 83
# img_array[0,0] = 85
# img_array[0,0] = 33
# img_array[0,0] = 55
# img_array[0,0] = 6
# img_array[0,0] = 59
# img_array[0,0] = 20
# img_array[0,0] = 25
# img_array[0,0] = 0
# img_array[0,0] = 0
# img_array[0,0] = 52
# img_array[0,0] = 0
# img_array[0,0] = 45
# img_array[0,0] = 10
# img_array[0,0] = 93
# img_array[0,0] = 10
# img_array[0,0] = 54
# img_array[0,0] = 66
# img_array[0,0] = 79
# img_array[0,0] = 86
# img_array[0,0] = 80
# img_array[0,0] = 81
# img_array[0,0] = 43
# img_array[0,0] = 93
# img_array[0,0] = 0
# img_array[0,0] = 46
# img_array[0,0] = 18
# img_array[0,0] = 98
# img_array[0,0] = 75
# img_array[0,0] = 87
# img_array[0,0] = 5
# img_array[0,0] = 15
# img_array[0,0] = 70
# img_array[0,0] = 3
# img_array[0,0] = 76
# img_array[0,0] = 46
# img_array[0,0] = 68
# img_array[0,0] = 1
# img_array[0,0] = 88
# img_array[0,0] = 62
# img_array[0,0] = 31
# img_array[0,0] = 100
# img_array[0,0] = 59
# img_array[0,0] = 22
# img_array[0,0] = 48
# img_array[0,0] = 96
# img_array[0,0] = 50
# img_array[0,0] = 48
# img_array[0,0] = 57
# img_array[0,0] = 13
# img_array[0,0] = 31
# img_array[0,0] = 0
# img_array[0,1] = 97
# img_array[0,0] = 13
# img_array[0,0] = 39
# img_array[0,0] = 1
# img_array[0,0] = 34
# img_array[0,0] = 64
# img_array[0,0] = 4
# img_array[0,0] = 39
# img_array[0,0] = 92
# img_array[0,0] = 39
# img_array[0,0] = 21
# img_array[0,0] = 58
# img_array[0,0] = 14
# img_array[0,0] = 17
# img_array[0,0] = 44
# img_array[0,0] = 84
# img_array[0,0] = 6
# img_array[0,0] = 99
# img_array[0,0] = 12
# img_array[0,0] = 66
# img_array[0,0] = 100
# img_array[0,0] = 99
# img_array[0,0] = 60
# img_array[0,0] = 70
# img_array[0,0] = 8
# img_array[0,0] = 15
# img_array[0,0] = 24
# img_array[0,1] = 100
# img_array[0,0] = 93
# img_array[0,0] = 24
# img_array[0,0] = 64
# img_array[0,0] = 39
# img_array[0,0] = 88
# img_array[0,0] = 85
# img_array[0,0] = 76
# img_array[0,0] = 82
# img_array[0,0] = 98
# img_array[0,0] = 77
# img_array[0,0] = 49
# img_array[0,0] = 16
# img_array[0,0] = 36
# img_array[0,0] = 80
# img_array[0,0] = 34
# img_array[0,0] = 0
# img_array[0,0] = 100
# img_array[0,0] = 66
# img_array[0,0] = 35
# img_array[0,0] = 24
# img_array[0,0] = 39
# img_array[0,0] = 16
# img_array[0,0] = 72
# img_array[0,0] = 71
# img_array[0,0] = 2
# img_array[0,0] = 64
# img_array[0,0] = 29
# img_array[0,0] = 56
# img_array[0,0] = 8
# img_array[0,0] = 81
# img_array[0,0] = 95
# img_array[0,0] = 72
# img_array[0,0] = 65
# img_array[0,0] = 72
# img_array[0,0] = 16
# img_array[0,0] = 41
# img_array[0,0] = 58
# img_array[0,0] = 86
# img_array[0,1] = 100
# img_array[0,0] = 59
# img_array[0,0] = 30
# img_array[0,0] = 21
# img_array[0,0] = 33
# img_array[0,0] = 98
# img_array[0,0] = 52
# img_array[0,0] = 35
# img_array[0,0] = 95
# img_array[0,0] = 12
# img_array[0,0] = 12
# img_array[0,0] = 26
# img_array[0,0] = 31
# img_array[0,0] = 76
# img_array[0,0] = 46
# img_array[0,0] = 55
# img_array[0,0] = 100
# img_array[0,0] = 32
# img_array[0,0] = 20
# img_array[0,0] = 45
# img_array[0,0] = 7
# img_array[0,0] = 38
# img_array[0,0] = 60
# img_array[0,0] = 0
# img_array[0,0] = 41
# img_array[0,0] = 28
# img_array[0,0] = 44
# img_array[0,0] = 72
# img_array[0,0] = 51
# img_array[0,0] = 75
# img_array[0,0] = 86
# img_array[0,0] = 84
# img_array[0,0] = 7
# img_array[0,0] = 7
# img_array[0,0] = 26
# img_array[0,0] = 67
# img_array[0,0] = 71
# img_array[0,0] = 79
# img_array[0,0] = 30
# img_array[0,0] = 98
# img_array[0,0] = 60
# img_array[0,0] = 51
# img_array[0,0] = 21
# img_array[0,0] = 75
# img_array[0,0] = 8
# img_array[0,0] = 48
# img_array[0,0] = 83
# img_array[0,0] = 76
# img_array[0,0] = 91
# img_array[0,0] = 96
# img_array[0,0] = 67
# img_array[0,0] = 7
# img_array[0,0] = 39
# img_array[0,0] = 71
# img_array[0,0] = 88
# img_array[0,0] = 94
# img_array[0,0] = 32
# img_array[0,0] = 79
# img_array[0,0] = 54
# img_array[0,0] = 91
# img_array[0,0] = 14
# img_array[0,0] = 48
# img_array[0,0] = 83
# img_array[0,0] = 95
# img_array[0,0] = 55
# img_array[0,0] = 4
# img_array[0,0] = 33
# img_array[0,0] = 46
# img_array[0,0] = 43
# img_array[0,0] = 53
# img_array[0,0] = 45
# img_array[0,0] = 98
# img_array[0,0] = 1
# img_array[0,0] = 72
# img_array[0,0] = 47
# img_array[0,0] = 54
# img_array[0,0] = 39
# img_array[0,0] = 19
# img_array[0,0] = 83
# img_array[0,0] = 73
# img_array[0,0] = 98
# img_array[0,0] = 90
# img_array[0,0] = 15
# img_array[0,0] = 31
# img_array[0,0] = 2
# img_array[0,0] = 30
# img_array[0,0] = 100
# img_array[0,0] = 80
# img_array[0,0] = 75
# img_array[0,0] = 9
# img_array[0,0] = 95
# img_array[0,0] = 52
# img_array[0,0] = 46
# img_array[0,0] = 78
# img_array[0,0] = 45
# img_array[0,0] = 65
# img_array[0,0] = 77
# img_array[0,0] = 18
# img_array[0,0] = 42
# img_array[0,0] = 79
# img_array[0,0] = 81
# img_array[0,0] = 58
# img_array[0,0] = 28
# img_array[0,0] = 37
# img_array[0,0] = 39
# img_array[0,0] = 73
# img_array[0,0] = 13
# img_array[0,0] = 11
# img_array[0,0] = 66
# img_array[0,0] = 81
# img_array[0,0] = 83
# img_array[0,0] = 64
# img_array[0,0] = 79
# img_array[0,0] = 28
# img_array[0,0] = 42
# img_array[0,0] = 18
# img_array[0,0] = 32
# img_array[0,0] = 8
# img_array[0,0] = 1
# img_array[0,0] = 2
# img_array[0,0] = 8
# img_array[0,0] = 83
# img_array[0,0] = 27
# img_array[0,0] = 100
# img_array[0,1] = 96
# img_array[0,1] = 100
# img_array[0,0] = 45
# img_array[0,0] = 88
# img_array[0,0] = 7
# img_array[0,0] = 37
# img_array[0,0] = 49
# img_array[0,0] = 54
# img_array[0,0] = 77
# img_array[0,0] = 34
# img_array[0,0] = 11
# img_array[0,0] = 27
# img_array[0,0] = 36
# img_array[0,0] = 87
# img_array[0,0] = 45
# img_array[0,0] = 67
# img_array[0,0] = 62
# img_array[0,0] = 67
# img_array[0,0] = 6
# img_array[0,0] = 72
# img_array[0,0] = 85
# img_array[0,0] = 37
# img_array[0,0] = 71
# img_array[0,0] = 100
# img_array[0,0] = 15
# img_array[0,0] = 37
# img_array[0,0] = 27
# img_array[0,0] = 59
# img_array[0,0] = 65
# img_array[0,0] = 49
# img_array[0,0] = 28
# img_array[0,0] = 9
# img_array[0,0] = 4
# img_array[0,0] = 17
# img_array[0,0] = 54
# img_array[0,0] = 65
# img_array[0,0] = 67
# img_array[0,0] = 86
# img_array[0,0] = 71
# img_array[0,0] = 90
# img_array[0,0] = 100
# img_array[0,0] = 84
# img_array[0,0] = 93
# img_array[0,0] = 99
# img_array[0,0] = 15
# img_array[0,0] = 6
# img_array[0,0] = 86
# img_array[0,0] = 23
# img_array[0,0] = 95
# img_array[0,0] = 65
# img_array[0,0] = 71
# img_array[0,0] = 18
# img_array[0,0] = 66
# img_array[0,0] = 71
# img_array[0,0] = 67
# img_array[0,0] = 10
# img_array[0,0] = 42
# img_array[0,0] = 29
# img_array[0,0] = 58
# img_array[0,0] = 72
# img_array[0,0] = 10
# img_array[0,0] = 91
# img_array[0,0] = 73
# img_array[0,0] = 75
# img_array[0,0] = 91
# img_array[0,0] = 64
# img_array[0,0] = 35
# img_array[0,0] = 78
# img_array[0,0] = 91
# img_array[0,0] = 8
# img_array[0,0] = 19
# img_array[0,0] = 67
# img_array[0,0] = 78
# img_array[0,0] = 77
# img_array[0,0] = 39
# img_array[0,0] = 38
# img_array[0,0] = 3
# img_array[0,0] = 62
# img_array[0,0] = 69
# img_array[0,0] = 88
# img_array[0,0] = 49
# img_array[0,0] = 61
# img_array[0,0] = 70
# img_array[0,0] = 6
# img_array[0,0] = 89
# img_array[0,0] = 90
# img_array[0,0] = 39
# img_array[0,0] = 94
# img_array[0,0] = 25
# img_array[0,0] = 26
# img_array[0,0] = 96
# img_array[0,0] = 65
# img_array[0,0] = 44
# img_array[0,0] = 34
# img_array[0,0] = 23
# img_array[0,0] = 20
# img_array[0,0] = 52
# img_array[0,0] = 46
# img_array[0,0] = 24
# img_array[0,0] = 84
# img_array[0,0] = 76
# img_array[0,0] = 9
# img_array[0,0] = 79
# img_array[0,0] = 61
# img_array[0,0] = 57
# img_array[0,0] = 100
# img_array[0,0] = 88
# img_array[0,0] = 95
# img_array[0,0] = 60
# img_array[0,0] = 88
# img_array[0,0] = 73
# img_array[0,0] = 4
# img_array[0,0] = 84
# img_array[0,0] = 67
# img_array[0,0] = 14
# img_array[0,0] = 2
# img_array[0,0] = 16
# img_array[0,0] = 17
# img_array[0,0] = 51
# img_array[0,0] = 82
# img_array[0,0] = 52
# img_array[0,0] = 44
# img_array[0,0] = 42
# img_array[0,0] = 11
# img_array[0,0] = 11
# img_array[0,0] = 80
# img_array[0,0] = 32
# img_array[0,0] = 99
# img_array[0,0] = 80
# img_array[0,0] = 91
# img_array[0,0] = 61
# img_array[0,0] = 67
# img_array[0,0] = 36
# img_array[0,0] = 0
# img_array[0,0] = 32
# img_array[0,0] = 36
# img_array[0,0] = 12
# img_array[0,0] = 94
# img_array[0,0] = 34
# img_array[0,0] = 18
# img_array[0,0] = 34
# img_array[0,0] = 29
# img_array[0,0] = 75
# img_array[0,0] = 18
# img_array[0,0] = 95
# img_array[0,0] = 12
# img_array[0,0] = 48
# img_array[0,1] = 99
# img_array[0,0] = 29
# img_array[0,0] = 81
# img_array[0,0] = 95
# img_array[0,0] = 96
# img_array[0,0] = 75
# img_array[0,0] = 70
# img_array[0,0] = 12
# img_array[0,0] = 41
# img_array[0,0] = 72
# img_array[0,0] = 91
# img_array[0,0] = 9
# img_array[0,0] = 91
# img_array[0,0] = 96
# img_array[0,0] = 75
# img_array[0,0] = 25
# img_array[0,0] = 59
# img_array[0,0] = 87
# img_array[0,1] = 70
# img_array[0,0] = 8
# img_array[0,0] = 66
# img_array[0,0] = 70
# img_array[0,0] = 44
# img_array[0,0] = 29
# img_array[0,0] = 75
# img_array[0,0] = 90
# img_array[0,0] = 71
# img_array[0,0] = 36
# img_array[0,0] = 82
# img_array[0,0] = 97
# img_array[0,0] = 61
# img_array[0,0] = 66
# img_array[0,0] = 55
# img_array[0,1] = 99
# img_array[0,0] = 53
# img_array[0,0] = 56
# img_array[0,0] = 57
# img_array[0,0] = 43
# img_array[0,0] = 98
# img_array[0,0] = 84
# img_array[0,0] = 25
# img_array[0,0] = 25
# img_array[0,1] = 85
# img_array[0,0] = 42
# img_array[0,0] = 87
# img_array[0,0] = 34
# img_array[0,0] = 51
# img_array[0,0] = 96
# img_array[0,0] = 44
# img_array[0,0] = 71
# img_array[0,0] = 10
# img_array[0,0] = 27
# img_array[0,0] = 60
# img_array[0,0] = 25
# img_array[0,0] = 40
# img_array[0,0] = 53
# img_array[0,0] = 77
# img_array[0,0] = 75
# img_array[0,0] = 2
# img_array[0,0] = 20
# img_array[0,0] = 92
# img_array[0,0] = 21
# img_array[0,0] = 36
# img_array[0,0] = 22
# img_array[0,0] = 57
# img_array[0,0] = 68
# img_array[0,0] = 65
# img_array[0,0] = 98
# img_array[0,0] = 33
# img_array[0,0] = 81
# img_array[0,0] = 35
# img_array[0,0] = 94
# img_array[0,0] = 46
# img_array[0,0] = 9
# img_array[0,0] = 87
# img_array[0,0] = 11
# img_array[0,0] = 65
# img_array[0,0] = 95
# img_array[0,0] = 25
# img_array[0,0] = 61
# img_array[0,0] = 40
# img_array[0,0] = 47
# img_array[0,0] = 33
# img_array[0,0] = 24
# img_array[0,0] = 45
# img_array[0,0] = 34
# img_array[0,0] = 99
# img_array[0,0] = 47
# img_array[0,0] = 86
# img_array[0,0] = 38
# img_array[0,0] = 47
# img_array[0,0] = 68
# img_array[0,0] = 34
# img_array[0,0] = 12
# img_array[0,0] = 78
# img_array[0,0] = 80
# img_array[0,0] = 39
# img_array[0,0] = 66
# img_array[0,0] = 57
# img_array[0,0] = 44
# img_array[0,0] = 86
# img_array[0,0] = 34
# img_array[0,0] = 79
# img_array[0,0] = 82
# img_array[0,0] = 87
# img_array[0,0] = 45
# img_array[0,0] = 85
# img_array[0,0] = 94
# img_array[0,0] = 35
# img_array[0,0] = 64
# img_array[0,0] = 47
# img_array[0,0] = 8
# img_array[0,0] = 65
# img_array[0,0] = 53
# img_array[0,0] = 55
# img_array[0,0] = 53
# img_array[0,0] = 7
# img_array[0,0] = 10
# img_array[0,0] = 59
# img_array[0,0] = 30
# img_array[0,0] = 52
# img_array[0,0] = 31
# img_array[0,0] = 41
# img_array[0,0] = 51
# img_array[0,0] = 69
# img_array[0,0] = 37
# img_array[0,0] = 5
# img_array[0,0] = 28
# img_array[0,0] = 4
# img_array[0,0] = 1
# img_array[0,0] = 31
# img_array[0,0] = 51
# img_array[0,0] = 9
# img_array[0,0] = 65
# img_array[0,0] = 50
# img_array[0,0] = 35
# img_array[0,0] = 92
# img_array[0,0] = 9
# img_array[0,0] = 41
# img_array[0,0] = 1
# img_array[0,0] = 13
# img_array[0,0] = 61
# img_array[0,0] = 35
# img_array[0,0] = 29
# img_array[0,0] = 41
# img_array[0,0] = 75
# img_array[0,0] = 83
# img_array[0,0] = 66
# img_array[0,0] = 88
# img_array[0,0] = 85
# img_array[0,0] = 20
# img_array[0,0] = 80
# img_array[0,0] = 32
# img_array[0,0] = 1
# img_array[0,0] = 8
# img_array[0,0] = 90
# img_array[0,0] = 63
# img_array[0,0] = 42
# img_array[0,0] = 56
# img_array[0,0] = 16
# img_array[0,0] = 80
# img_array[0,0] = 0
# img_array[0,0] = 75
# img_array[0,0] = 20
# img_array[0,0] = 79
# img_array[0,0] = 52
# img_array[0,0] = 64
# img_array[0,0] = 81
# img_array[0,0] = 50
# img_array[0,0] = 7
# img_array[0,1] = 99
# img_array[0,0] = 5
# img_array[0,0] = 19
# img_array[0,0] = 3
# img_array[0,0] = 85
# img_array[0,0] = 94
# img_array[0,0] = 56
# img_array[0,0] = 95
# img_array[0,0] = 5
# img_array[0,1] = 96
# img_array[0,0] = 42
# img_array[0,0] = 65
# img_array[0,0] = 55
# img_array[0,0] = 9
# img_array[0,0] = 79
# img_array[0,0] = 92
# img_array[0,0] = 24
# img_array[0,0] = 46
# img_array[0,0] = 36
# img_array[0,0] = 91
# img_array[0,0] = 6
# img_array[0,0] = 29
# img_array[0,0] = 1
# img_array[0,0] = 48
# img_array[0,0] = 47
# img_array[0,0] = 60
# img_array[0,0] = 29
# img_array[0,0] = 0
# img_array[0,0] = 73
# img_array[0,0] = 20
# img_array[0,0] = 59
# img_array[0,0] = 98
# img_array[0,0] = 0
# img_array[0,0] = 30
# img_array[0,0] = 40
# img_array[0,0] = 58
# img_array[0,0] = 84
# img_array[0,0] = 34
# img_array[0,0] = 80
# img_array[0,0] = 48
# img_array[0,0] = 0
# img_array[0,0] = 73
# img_array[0,0] = 99
# img_array[0,0] = 36
# img_array[0,0] = 16
# img_array[0,0] = 82
# img_array[0,0] = 17
# img_array[0,0] = 70
# img_array[0,0] = 60
# img_array[0,0] = 16
# img_array[0,1] = 59
# img_array[0,0] = 87
# img_array[0,0] = 79
# img_array[0,0] = 13
# img_array[0,0] = 28
# img_array[0,0] = 94
# img_array[0,0] = 87
# img_array[0,0] = 96
# img_array[0,0] = 80
# img_array[0,0] = 36
# img_array[0,0] = 82
# img_array[0,0] = 25
# img_array[0,0] = 62
# img_array[0,0] = 94
# img_array[0,0] = 86
# img_array[0,0] = 61
# img_array[0,0] = 83
# img_array[0,0] = 50
# img_array[0,0] = 23
# img_array[0,0] = 36
# img_array[0,0] = 55
# img_array[0,0] = 57
# img_array[0,0] = 51
# img_array[0,0] = 73
# img_array[0,0] = 74
# img_array[0,0] = 24
# img_array[0,0] = 6
# img_array[0,0] = 56
# img_array[0,0] = 41
# img_array[0,0] = 15
# img_array[0,0] = 68
# img_array[0,0] = 0
# img_array[0,0] = 81
# img_array[0,0] = 48
# img_array[0,0] = 48
# img_array[0,0] = 62
# img_array[0,0] = 18
# img_array[0,0] = 98
# img_array[0,0] = 39
# img_array[0,0] = 47
# img_array[0,0] = 40
# img_array[0,0] = 95
# img_array[0,0] = 95
# img_array[0,0] = 76
# img_array[0,0] = 21
# img_array[0,0] = 89
# img_array[0,0] = 33
# img_array[0,0] = 67
# img_array[0,0] = 40
# img_array[0,0] = 75
# img_array[0,0] = 80
# img_array[0,0] = 68
# img_array[0,0] = 63
# img_array[0,0] = 43
# img_array[0,0] = 44
# img_array[0,0] = 53
# img_array[0,0] = 34
# img_array[0,0] = 47
# img_array[0,0] = 36
# img_array[0,0] = 93
# img_array[0,0] = 60
# img_array[0,0] = 84
# img_array[0,0] = 37
# img_array[0,0] = 52
# img_array[0,0] = 35
# img_array[0,0] = 62
# img_array[0,0] = 50
# img_array[0,0] = 59
# img_array[0,0] = 57
# img_array[0,0] = 39
# img_array[0,0] = 94
# img_array[0,0] = 50
# img_array[0,0] = 21
# img_array[0,0] = 36
# img_array[0,0] = 14
# img_array[0,0] = 73
# img_array[0,0] = 59
# img_array[0,1] = 100
# img_array[0,0] = 78
# img_array[0,0] = 73
# img_array[0,0] = 71
# img_array[0,0] = 11
# img_array[0,0] = 20
# img_array[0,0] = 68
# img_array[0,0] = 99
# img_array[0,0] = 77
# img_array[0,0] = 86
# img_array[0,0] = 21
# img_array[0,0] = 69
# img_array[0,0] = 44
# img_array[0,0] = 56
# img_array[0,0] = 35
# img_array[0,0] = 86
# img_array[0,0] = 1
# img_array[0,0] = 25
# img_array[0,0] = 95
# img_array[0,0] = 59
# img_array[0,0] = 39
# img_array[0,0] = 58
# img_array[0,0] = 96
# img_array[0,0] = 91
# img_array[0,0] = 97
# img_array[0,0] = 84
# img_array[0,0] = 5
# img_array[0,0] = 52
# img_array[0,0] = 31
# img_array[0,0] = 84
# img_array[0,0] = 1
# img_array[0,0] = 67
# img_array[0,0] = 12
# img_array[0,0] = 30
# img_array[0,0] = 13
# img_array[0,0] = 85
# img_array[0,0] = 32
# img_array[0,0] = 23
# img_array[0,0] = 100
# img_array[0,0] = 17
# img_array[0,0] = 26
# img_array[0,0] = 1
# img_array[0,0] = 63
# img_array[0,0] = 0
# img_array[0,0] = 45
# img_array[0,0] = 35
# img_array[0,0] = 62
# img_array[0,0] = 24
# img_array[0,0] = 89
# img_array[0,0] = 12
# img_array[0,0] = 98
# img_array[0,0] = 44
# img_array[0,0] = 93
# img_array[0,1] = 98
# img_array[0,0] = 15
# img_array[0,0] = 77
# img_array[0,0] = 27
# img_array[0,0] = 8
# img_array[0,0] = 56
# img_array[0,0] = 60
# img_array[0,0] = 31
# img_array[0,0] = 50
# img_array[0,0] = 13
# img_array[0,0] = 31
# img_array[0,0] = 64
# img_array[0,0] = 28
# img_array[0,0] = 99
# img_array[0,0] = 0
# img_array[0,0] = 97
# img_array[0,0] = 44
# img_array[0,0] = 13
# img_array[0,0] = 83
# img_array[0,0] = 75
# img_array[0,0] = 70
# img_array[0,0] = 0
# img_array[0,0] = 62
# img_array[0,0] = 83
# img_array[0,0] = 9
# img_array[0,0] = 97
# img_array[0,0] = 95
# img_array[0,0] = 37
# img_array[0,0] = 72
# img_array[0,0] = 38
# img_array[0,0] = 97
# img_array[0,0] = 64
# img_array[0,0] = 58
# img_array[0,0] = 85
# img_array[0,0] = 59
# img_array[0,0] = 57
# img_array[0,0] = 36
# img_array[0,0] = 62
# img_array[0,0] = 82
# img_array[0,0] = 73
# img_array[0,0] = 51
# img_array[0,1] = 98
# img_array[0,0] = 100
# img_array[0,0] = 12
# img_array[0,0] = 69
# img_array[0,0] = 15
# img_array[0,0] = 62
# img_array[0,0] = 95
# img_array[0,0] = 74
# img_array[0,0] = 77
# img_array[0,0] = 27
# img_array[0,0] = 91
# img_array[0,0] = 96
# img_array[0,0] = 73
# img_array[0,0] = 67
# img_array[0,0] = 63
# img_array[0,0] = 31
# img_array[0,0] = 73
# img_array[0,0] = 56
# img_array[0,0] = 35
# img_array[0,0] = 50
# img_array[0,0] = 28
# img_array[0,0] = 86
# img_array[0,0] = 82
# img_array[0,0] = 94
# img_array[0,0] = 0
# img_array[0,0] = 41
# img_array[0,0] = 86
# img_array[0,0] = 68
# img_array[0,0] = 13
# img_array[0,0] = 1
# img_array[0,0] = 43
# img_array[0,0] = 66
# img_array[0,0] = 91
# img_array[0,0] = 19
# img_array[0,0] = 20
# img_array[0,0] = 52
# img_array[0,0] = 100
# img_array[0,0] = 29
# img_array[0,0] = 23
# img_array[0,0] = 33
# img_array[0,0] = 62
# img_array[0,0] = 34
# img_array[0,0] = 33
# img_array[0,0] = 100
# img_array[0,0] = 94
# img_array[0,0] = 6
# img_array[0,0] = 0
# img_array[0,0] = 11
# img_array[0,0] = 1
# img_array[0,0] = 72
# img_array[0,0] = 18
# img_array[0,0] = 78
# img_array[0,0] = 78
# img_array[0,0] = 79
# img_array[0,0] = 63
# img_array[0,0] = 20
# img_array[0,0] = 46
# img_array[0,0] = 0
# img_array[0,0] = 73
# img_array[0,0] = 69
# img_array[0,0] = 44
# img_array[0,0] = 100
# img_array[0,0] = 22
# img_array[0,0] = 100
# img_array[0,0] = 73
# img_array[0,0] = 66
# img_array[0,0] = 65
# img_array[0,0] = 0
# img_array[0,0] = 19
# img_array[0,0] = 70
# img_array[0,0] = 83
# img_array[0,1] = 100
# img_array[0,0] = 98
# img_array[0,0] = 57
# img_array[0,0] = 92
# img_array[0,0] = 89
# img_array[0,0] = 56
# img_array[0,0] = 50
# img_array[0,0] = 55
# img_array[0,0] = 27
# img_array[0,1] = 99
# img_array[0,0] = 31
# img_array[0,0] = 0
# img_array[0,0] = 49
# img_array[0,0] = 81
# img_array[0,0] = 87
# img_array[0,0] = 92
# img_array[0,0] = 66
# img_array[0,0] = 32
# img_array[0,0] = 20
# img_array[0,0] = 91
# img_array[0,0] = 70
# img_array[0,0] = 81
# img_array[0,0] = 17
# img_array[0,0] = 76
# img_array[0,0] = 93
# img_array[0,0] = 77
# img_array[0,0] = 0
# img_array[0,0] = 92
# img_array[0,0] = 84
# img_array[0,0] = 82
# img_array[0,0] = 23
# img_array[0,0] = 26
# img_array[0,0] = 95
# img_array[0,0] = 83
# img_array[0,0] = 96
# img_array[0,0] = 93
# img_array[0,0] = 70
# img_array[0,0] = 34
# img_array[0,0] = 82
# img_array[0,0] = 32
# img_array[0,0] = 55
# img_array[0,0] = 82
# img_array[0,0] = 60
# img_array[0,0] = 78
# img_array[0,0] = 22
# img_array[0,0] = 24
# img_array[0,0] = 79
# img_array[0,0] = 50
# img_array[0,0] = 53
# img_array[0,0] = 16
# img_array[0,0] = 45
# img_array[0,0] = 18
# img_array[0,0] = 25
# img_array[0,0] = 71
# img_array[0,0] = 59
# img_array[0,0] = 95
# img_array[0,0] = 45
# img_array[0,0] = 50
# img_array[0,0] = 80
# img_array[0,0] = 11
# img_array[0,0] = 96
# img_array[0,0] = 11
# img_array[0,0] = 23
# img_array[0,0] = 41
# img_array[0,0] = 55
# img_array[0,0] = 81
# img_array[0,0] = 48
# img_array[0,0] = 26
# img_array[0,0] = 88
# img_array[0,0] = 35
# img_array[0,0] = 98
# img_array[0,0] = 62
# img_array[0,0] = 26
# img_array[0,0] = 44
# img_array[0,0] = 37
# img_array[0,0] = 25
# img_array[0,0] = 55
# img_array[0,0] = 70
# img_array[0,0] = 83
# img_array[0,0] = 59
# img_array[0,0] = 44
# img_array[0,0] = 34
# img_array[0,0] = 46
# img_array[0,0] = 96
# img_array[0,0] = 0
# img_array[0,0] = 98
# img_array[0,0] = 3
# img_array[0,0] = 63
# img_array[0,0] = 74
# img_array[0,0] = 89
# img_array[0,0] = 59
# img_array[0,0] = 61
# img_array[0,0] = 89
# img_array[0,0] = 27
# img_array[0,0] = 31
# img_array[0,0] = 45
# img_array[0,0] = 82
# img_array[0,0] = 7
# img_array[0,0] = 60
# img_array[0,0] = 60
# img_array[0,0] = 20
# img_array[0,0] = 47
# img_array[0,0] = 60
# img_array[0,0] = 3
# img_array[0,0] = 74
# img_array[0,0] = 23
# img_array[0,0] = 38
# img_array[0,0] = 0
# img_array[0,0] = 75
# img_array[0,0] = 38
# img_array[0,0] = 9
# img_array[0,0] = 68
# img_array[0,0] = 49
# img_array[0,0] = 53
# img_array[0,0] = 77
# img_array[0,0] = 40
# img_array[0,0] = 20
# img_array[0,0] = 51
# img_array[0,0] = 54
# img_array[0,0] = 85
# img_array[0,0] = 77
# img_array[0,0] = 11
# img_array[0,0] = 88
# img_array[0,0] = 37
# img_array[0,0] = 16
# img_array[0,0] = 97
# img_array[0,0] = 66
# img_array[0,0] = 41
# img_array[0,0] = 84
# img_array[0,0] = 46
# img_array[0,0] = 28
# img_array[0,0] = 93
# img_array[0,0] = 72
# img_array[0,0] = 41
# img_array[0,0] = 93
# img_array[0,0] = 12
# img_array[0,0] = 76
# img_array[0,1] = 94
# img_array[0,0] = 26
# img_array[0,0] = 66
# img_array[0,0] = 86
# img_array[0,0] = 81
# img_array[0,0] = 55
# img_array[0,0] = 26
# img_array[0,0] = 94
# img_array[0,0] = 0
# img_array[0,0] = 80
# img_array[0,0] = 11
# img_array[0,0] = 84
# img_array[0,0] = 32
# img_array[0,0] = 28
# img_array[0,0] = 5
# img_array[0,0] = 69
# img_array[0,0] = 11
# img_array[0,0] = 94
# img_array[0,0] = 65
# img_array[0,0] = 85
# img_array[0,0] = 91
# img_array[0,0] = 37
# img_array[0,0] = 95
# img_array[0,0] = 64
# img_array[0,0] = 48
# img_array[0,0] = 14
# img_array[0,0] = 13
# img_array[0,0] = 90
# img_array[0,0] = 16
# img_array[0,0] = 31
# img_array[0,0] = 72
# img_array[0,0] = 63
# img_array[0,0] = 52
# img_array[0,0] = 73
# img_array[0,0] = 97
# img_array[0,0] = 77
# img_array[0,0] = 72
# img_array[0,0] = 74
# img_array[0,0] = 3
# img_array[0,0] = 63
# img_array[0,0] = 0
# img_array[0,0] = 0
# img_array[0,0] = 96
# img_array[0,0] = 53
# img_array[0,0] = 94
# img_array[0,0] = 97
# img_array[0,0] = 22
# img_array[0,0] = 26
# img_array[0,0] = 61
# img_array[0,0] = 80
# img_array[0,0] = 38
# img_array[0,0] = 53
# img_array[0,0] = 75
# img_array[0,0] = 47
# img_array[0,0] = 69
# img_array[0,0] = 2
# img_array[0,0] = 27
# img_array[0,0] = 69
# img_array[0,0] = 64
# img_array[0,0] = 89
# img_array[0,0] = 10
# img_array[0,0] = 77
# img_array[0,0] = 48
# img_array[0,0] = 12
# img_array[0,0] = 98
# img_array[0,0] = 56
# img_array[0,0] = 3
# img_array[0,0] = 77
# img_array[0,0] = 96
# img_array[0,0] = 54
# img_array[0,0] = 94
# img_array[0,0] = 65
# img_array[0,0] = 10
# img_array[0,0] = 0
# img_array[0,0] = 40
# img_array[0,0] = 71
# img_array[0,0] = 100
# img_array[0,0] = 55
# img_array[0,0] = 91
# img_array[0,0] = 33
# img_array[0,0] = 20
# img_array[0,0] = 98
# img_array[0,0] = 76
# img_array[0,0] = 87
# img_array[0,0] = 83
# img_array[0,0] = 87
# img_array[0,0] = 68
# img_array[0,0] = 99
# img_array[0,0] = 82
# img_array[0,0] = 49
# img_array[0,0] = 62
# img_array[0,0] = 75
# img_array[0,0] = 74
# img_array[0,0] = 87
# img_array[0,0] = 75
# img_array[0,0] = 27
# img_array[0,0] = 33
# img_array[0,0] = 47
# img_array[0,0] = 66
# img_array[0,0] = 45
# img_array[0,0] = 80
# img_array[0,0] = 41
# img_array[0,0] = 59
# img_array[0,0] = 75
# img_array[0,0] = 97
# img_array[0,0] = 35
# img_array[0,0] = 18
# img_array[0,0] = 71
# img_array[0,0] = 44
# img_array[0,0] = 28
# img_array[0,0] = 96
# img_array[0,0] = 92
# img_array[0,0] = 99
# img_array[0,0] = 75
# img_array[0,0] = 2
# img_array[0,0] = 53
# img_array[0,0] = 75
# img_array[0,0] = 28
# img_array[0,0] = 98
# img_array[0,0] = 84
# img_array[0,0] = 44
# img_array[0,0] = 92
# img_array[0,0] = 93
# img_array[0,0] = 69
# img_array[0,0] = 58
# img_array[0,0] = 83
# img_array[0,0] = 30
# img_array[0,0] = 29
# img_array[0,0] = 83
# img_array[0,0] = 98
# img_array[0,0] = 97
# img_array[0,0] = 72
# img_array[0,0] = 67
# img_array[0,0] = 99
# img_array[0,0] = 81
# img_array[0,0] = 72
# img_array[0,0] = 63
# img_array[0,0] = 71
# img_array[0,0] = 96
# img_array[0,0] = 98
# img_array[0,0] = 99
# img_array[0,0] = 64
# img_array[0,0] = 76
# img_array[0,0] = 8
# img_array[0,0] = 100
# img_array[0,0] = 98
# img_array[0,0] = 67
# img_array[0,0] = 83
# img_array[0,0] = 95
# img_array[0,0] = 92
# img_array[0,0] = 81
# img_array[0,0] = 72
# img_array[0,0] = 13
# img_array[0,0] = 1
# img_array[0,0] = 88
# img_array[0,0] = 13
# img_array[0,0] = 90
# img_array[0,0] = 97
# img_array[0,0] = 32
# img_array[0,0] = 13
# img_array[0,0] = 50
# img_array[0,0] = 60
# img_array[0,0] = 55
# img_array[0,0] = 94
# img_array[0,0] = 65
# img_array[0,1] = 97
# img_array[0,0] = 70
# img_array[0,0] = 21
# img_array[0,0] = 75
# img_array[0,0] = 44
# img_array[0,0] = 97
# img_array[0,0] = 65
# img_array[0,0] = 17
# img_array[0,0] = 62
# img_array[0,0] = 67
# img_array[0,0] = 95
# img_array[0,0] = 71
# img_array[0,0] = 95
# img_array[0,0] = 61
# img_array[0,0] = 48
# img_array[0,0] = 99
# img_array[0,0] = 43
# img_array[0,0] = 37
# img_array[0,0] = 33
# img_array[0,0] = 84
# img_array[0,0] = 53
# img_array[0,0] = 75
# img_array[0,0] = 67
# img_array[0,0] = 98
# img_array[0,0] = 34
# img_array[0,0] = 64
# img_array[0,0] = 52
# img_array[0,0] = 75
# img_array[0,0] = 54
# img_array[0,0] = 84
# img_array[0,0] = 85
# img_array[0,0] = 32
# img_array[0,0] = 22
# img_array[0,0] = 96
# img_array[0,0] = 40
# img_array[0,0] = 91
# img_array[0,0] = 13
# img_array[0,0] = 69
# img_array[0,0] = 86
# img_array[0,0] = 14
# img_array[0,0] = 78
# img_array[0,0] = 18
# img_array[0,0] = 93
# img_array[0,0] = 36
# img_array[0,0] = 84
# img_array[0,0] = 7
# img_array[0,0] = 86
# img_array[0,0] = 52
# img_array[0,0] = 86
# img_array[0,0] = 6
# img_array[0,0] = 69
# img_array[0,0] = 74
# img_array[0,0] = 40
# img_array[0,0] = 81
# img_array[0,0] = 100
# img_array[0,0] = 92
# img_array[0,0] = 53
# img_array[0,0] = 86
# img_array[0,0] = 13
# img_array[0,0] = 20
# img_array[0,0] = 53
# img_array[0,0] = 52
# img_array[0,0] = 52
# img_array[0,0] = 55
# img_array[0,0] = 86
# img_array[0,0] = 98
# img_array[0,0] = 95
# img_array[0,0] = 0
# img_array[0,0] = 65
# img_array[0,0] = 44
# img_array[0,1] = 100
# img_array[0,0] = 81
# img_array[0,0] = 63
# img_array[0,0] = 22
# img_array[0,0] = 92
# img_array[0,0] = 65
# img_array[0,0] = 82
# img_array[0,0] = 95
# img_array[0,0] = 30
# img_array[0,0] = 4
# img_array[0,0] = 53
# img_array[0,0] = 49
# img_array[0,0] = 61
# img_array[0,0] = 49
# img_array[0,0] = 22
# img_array[0,0] = 55
# img_array[0,0] = 0
# img_array[0,0] = 98
# img_array[0,0] = 75
# img_array[0,0] = 59
# img_array[0,0] = 72
# img_array[0,0] = 46
# img_array[0,0] = 63
# img_array[0,0] = 22
# img_array[0,0] = 42
# img_array[0,0] = 37
# img_array[0,0] = 84
# img_array[0,0] = 100
# img_array[0,0] = 1
# img_array[0,0] = 26
# img_array[0,0] = 88
# img_array[0,0] = 84
# img_array[0,0] = 49
# img_array[0,1] = 100
# img_array[0,0] = 20
# img_array[0,0] = 69
# img_array[0,0] = 93
# img_array[0,0] = 51
# img_array[0,0] = 0
# img_array[0,0] = 50
# img_array[0,0] = 21
# img_array[0,0] = 40
# img_array[0,0] = 59
# img_array[0,0] = 82
# img_array[0,0] = 39
# img_array[0,0] = 48
# img_array[0,0] = 30
# img_array[0,0] = 33
# img_array[0,0] = 78
# img_array[0,0] = 83
# img_array[0,0] = 50
# img_array[0,0] = 91
# img_array[0,0] = 60
# img_array[0,0] = 4
# img_array[0,0] = 86
# img_array[0,0] = 98
# img_array[0,0] = 91
# img_array[0,0] = 96
# img_array[0,0] = 33
# img_array[0,0] = 0
# img_array[0,0] = 25
# img_array[0,0] = 39
# img_array[0,0] = 61
# img_array[0,0] = 28
# img_array[0,0] = 33
# img_array[0,1] = 100
# img_array[0,0] = 61
# img_array[0,0] = 12
# img_array[0,0] = 88
# img_array[0,0] = 25
# img_array[0,0] = 32
# img_array[0,0] = 14
# img_array[0,0] = 92
# img_array[0,0] = 0
# img_array[0,0] = 72
# img_array[0,0] = 96
# img_array[0,0] = 91
# img_array[0,0] = 48
# img_array[0,0] = 56
# img_array[0,0] = 26
# img_array[0,0] = 52
# img_array[0,0] = 51
# img_array[0,0] = 96
# img_array[0,0] = 86
# img_array[0,0] = 0
# img_array[0,0] = 76
# img_array[0,0] = 11
# img_array[0,0] = 94
# img_array[0,0] = 97
# img_array[0,0] = 13
# img_array[0,0] = 64
# img_array[0,0] = 60
# img_array[0,0] = 36
# img_array[0,0] = 83
# img_array[0,0] = 0
# img_array[0,0] = 89
# img_array[0,0] = 56
# img_array[0,0] = 82
# img_array[0,0] = 67
# img_array[0,0] = 50
# img_array[0,0] = 86
# img_array[0,0] = 12
# img_array[0,0] = 84
# img_array[0,0] = 100
# img_array[0,0] = 27
# img_array[0,0] = 88
# img_array[0,0] = 27
# img_array[0,0] = 88
# img_array[0,0] = 83
# img_array[0,0] = 97
# img_array[0,0] = 30
# img_array[0,0] = 46
# img_array[0,0] = 92
# img_array[0,0] = 59
# img_array[0,0] = 87
# img_array[0,0] = 21
# img_array[0,0] = 35
# img_array[0,0] = 87
# img_array[0,0] = 72
# img_array[0,0] = 69
# img_array[0,0] = 86
# img_array[0,0] = 36
# img_array[0,0] = 52
# img_array[0,0] = 87
# img_array[0,0] = 100
# img_array[0,0] = 78
# img_array[0,0] = 8
# img_array[0,0] = 81
# img_array[0,0] = 72
# img_array[0,0] = 94
# img_array[0,0] = 79
# img_array[0,0] = 58
# img_array[0,1] = 100
# img_array[0,0] = 50
# img_array[0,0] = 65
# img_array[0,0] = 1
# img_array[0,0] = 88
# img_array[0,1] = 86
# img_array[0,0] = 46
# img_array[0,0] = 7
# img_array[0,0] = 77
# img_array[0,0] = 72
# img_array[0,0] = 12
# img_array[0,0] = 52
# img_array[0,0] = 2
# img_array[0,0] = 66
# img_array[0,0] = 97
# img_array[0,0] = 20
# img_array[0,0] = 24
# img_array[0,0] = 78
# img_array[0,0] = 67
# img_array[0,0] = 56
# img_array[0,0] = 97
# img_array[0,0] = 20
# img_array[0,1] = 96
# img_array[0,0] = 79
# img_array[0,0] = 46
# img_array[0,0] = 80
# img_array[0,0] = 37
# img_array[0,0] = 20
# img_array[0,0] = 30
# img_array[0,0] = 75
# img_array[0,0] = 87
# img_array[0,0] = 24
# img_array[0,0] = 44
# img_array[0,0] = 94
# img_array[0,1] = 92
# img_array[0,0] = 26
# img_array[0,0] = 37
# img_array[0,0] = 8
# img_array[0,0] = 54
# img_array[0,0] = 1
# img_array[0,0] = 40
# img_array[0,0] = 16
# img_array[0,0] = 96
# img_array[0,0] = 87
# img_array[0,0] = 57
# img_array[0,0] = 86
# img_array[0,0] = 30
# img_array[0,0] = 70
# img_array[0,0] = 18
# img_array[0,0] = 29
# img_array[0,0] = 78
# img_array[0,0] = 92
# img_array[0,0] = 73
# img_array[0,0] = 63
# img_array[0,0] = 52
# img_array[0,0] = 85
# img_array[0,0] = 75
# img_array[0,0] = 33
# img_array[0,0] = 29
# img_array[0,0] = 48
# img_array[0,0] = 43
# img_array[0,0] = 93
# img_array[0,0] = 28
# img_array[0,0] = 26
# img_array[0,0] = 33
# img_array[0,0] = 71
# img_array[0,0] = 48
# img_array[0,0] = 16
# img_array[0,0] = 55
# img_array[0,0] = 61
# img_array[0,0] = 100
# img_array[0,0] = 83
# img_array[0,0] = 100
# img_array[0,0] = 57
# img_array[0,0] = 82
# img_array[0,0] = 87
# img_array[0,0] = 65
# img_array[0,0] = 99
# img_array[0,0] = 34
# img_array[0,0] = 22
# img_array[0,0] = 71
# img_array[0,0] = 59
# img_array[0,0] = 63
# img_array[0,0] = 61
# img_array[0,0] = 77
# img_array[0,0] = 77
# img_array[0,0] = 85
# img_array[0,0] = 36
# img_array[0,0] = 47
# img_array[0,0] = 31
# img_array[0,0] = 96
# img_array[0,0] = 85
# img_array[0,0] = 57
# img_array[0,0] = 17
# img_array[0,0] = 73
# img_array[0,0] = 18
# img_array[0,0] = 78
# img_array[0,0] = 52
# img_array[0,0] = 52
# img_array[0,0] = 71
# img_array[0,0] = 92
# img_array[0,0] = 48
# img_array[0,0] = 28
# img_array[0,0] = 33
# img_array[0,0] = 20
# img_array[0,0] = 52
# img_array[0,0] = 41
# img_array[0,0] = 92
# img_array[0,0] = 75
# img_array[0,0] = 52
# img_array[0,0] = 55
# img_array[0,0] = 69
# img_array[0,0] = 99
# img_array[0,0] = 6
# img_array[0,0] = 84
# img_array[0,0] = 7
# img_array[0,0] = 77
# img_array[0,0] = 30
# img_array[0,0] = 87
# img_array[0,0] = 76
# img_array[0,0] = 97
# img_array[0,0] = 52
# img_array[0,0] = 49
# img_array[0,0] = 79
# img_array[0,0] = 92
# img_array[0,0] = 47
# img_array[0,0] = 72
# img_array[0,0] = 57
# img_array[0,0] = 63
# img_array[0,0] = 26
# img_array[0,0] = 71
# img_array[0,0] = 68
# img_array[0,0] = 92
# img_array[0,0] = 51
# img_array[0,0] = 98
# img_array[0,0] = 13
# img_array[0,0] = 57
# img_array[0,0] = 57
# img_array[0,0] = 99
# img_array[0,0] = 58
# img_array[0,0] = 93
# img_array[0,0] = 31
# img_array[0,0] = 57
# img_array[0,0] = 22
# img_array[0,0] = 58
# img_array[0,0] = 81
# img_array[0,0] = 100
# img_array[0,0] = 49
# img_array[0,0] = 24
# img_array[0,1] = 92
# img_array[0,0] = 61
# img_array[0,0] = 95
# img_array[0,0] = 79
# img_array[0,0] = 90
# img_array[0,0] = 21
# img_array[0,0] = 26
# img_array[0,0] = 78
# img_array[0,0] = 88
# img_array[0,0] = 48
# img_array[0,0] = 76
# img_array[0,0] = 56
# img_array[0,0] = 53
# img_array[0,0] = 78
# img_array[0,1] = 99
# img_array[0,0] = 20
# img_array[0,0] = 88
# img_array[0,0] = 44
# img_array[0,0] = 46
# img_array[0,0] = 41
# img_array[0,0] = 84
# img_array[0,0] = 74
# img_array[0,0] = 29
# img_array[0,0] = 70
# img_array[0,0] = 57
# img_array[0,0] = 52
# img_array[0,0] = 86
# img_array[0,0] = 83
# img_array[0,0] = 82
# img_array[0,0] = 44
# img_array[0,0] = 70
# img_array[0,0] = 19
# img_array[0,0] = 70
# img_array[0,1] = 99
# img_array[0,0] = 14
# img_array[0,0] = 61
# img_array[0,0] = 28
# img_array[0,1] = 74
# img_array[0,0] = 22
# img_array[0,0] = 25
# img_array[0,0] = 99
# img_array[0,0] = 38
# img_array[0,0] = 39
# img_array[0,0] = 60
# img_array[0,0] = 22
# img_array[0,0] = 32
# img_array[0,0] = 78
# img_array[0,0] = 92
# img_array[0,0] = 76
# img_array[0,0] = 52
# img_array[0,0] = 36
# img_array[0,0] = 52
# img_array[0,0] = 87
# img_array[0,1] = 91
# img_array[0,0] = 82
# img_array[0,0] = 34
# img_array[0,0] = 73
# img_array[0,0] = 39
# img_array[0,0] = 46
# img_array[0,0] = 34
# img_array[0,0] = 75
# img_array[0,0] = 15
# img_array[0,0] = 51
# img_array[0,0] = 94
# img_array[0,0] = 53
# img_array[0,0] = 82
# img_array[0,0] = 16
# img_array[0,0] = 51
# img_array[0,0] = 94
# img_array[0,0] = 56
# img_array[0,0] = 38
# img_array[0,0] = 88
# img_array[0,1] = 100
# img_array[0,0] = 64
# img_array[0,0] = 52
# img_array[0,0] = 70
# img_array[0,0] = 72
# ...
# img_array[0,1] = 99
# img_array[0,0] = 1
# img_array[0,1] = 86
# img_array[0,0] = 74
# img_array[0,1] = 99
# img_array[0,0] = 27
# img_array[0,0] = 13
# img_array[0,0] = 24
# img_array[0,0] = 56
# img_array[0,0] = 75
# img_array[0,0] = 17
# img_array[0,0] = 1
# img_array[0,0] = 62
# img_array[0,0] = 29
# img_array[0,0] = 58
# img_array[0,0] = 29
# img_array[0,0] = 92
# img_array[0,0] = 75
# img_array[0,0] = 35
# img_array[0,0] = 99
# img_array[0,0] = 100
# img_array[0,0] = 29
# img_array[0,0] = 93
# img_array[0,0] = 11
# img_array[0,0] = 50
# img_array[0,0] = 52
# img_array[0,0] = 51
# img_array[0,0] = 49
# img_array[0,0] = 83
# img_array[0,0] = 8
# img_array[0,0] = 0
# img_array[0,0] = 21
# img_array[0,0] = 48
# img_array[0,0] = 96
# img_array[0,1] = 100
# img_array[0,0] = 65
# img_array[0,0] = 18
# img_array[0,1] = 92
# img_array[0,0] = 93
# img_array[0,0] = 93
# img_array[0,0] = 90
# img_array[0,0] = 34
# img_array[0,0] = 58
# img_array[0,0] = 74
# img_array[0,0] = 95
# img_array[0,0] = 83
# img_array[0,0] = 72
# img_array[0,0] = 20
# img_array[0,0] = 25
# img_array[0,0] = 42
# img_array[0,0] = 31
# img_array[0,1] = 97
# img_array[0,0] = 91
# img_array[0,0] = 0
# img_array[0,0] = 1
# img_array[0,0] = 70
# img_array[0,1] = 98
# img_array[0,0] = 97
# img_array[0,0] = 69
# img_array[0,0] = 75
# img_array[0,0] = 9
# img_array[0,0] = 46
# img_array[0,1] = 100
# img_array[0,0] = 27
# img_array[0,0] = 68
# img_array[0,0] = 24
# img_array[0,0] = 23
# img_array[0,0] = 75
# img_array[0,0] = 76
# img_array[0,0] = 23
# img_array[0,0] = 95
# img_array[0,0] = 30
# img_array[0,0] = 90
# img_array[0,0] = 13
# img_array[0,0] = 84
# img_array[0,0] = 85
# img_array[0,0] = 20
# img_array[0,0] = 6
# img_array[0,0] = 0
# img_array[0,0] = 84
# img_array[0,0] = 15
# img_array[0,0] = 15
# img_array[0,0] = 16
# img_array[0,0] = 56
# img_array[0,0] = 90
# img_array[0,0] = 1
# img_array[0,0] = 51
# img_array[0,0] = 72
# img_array[0,1] = 98
# img_array[0,0] = 70
# img_array[0,0] = 86
# img_array[0,0] = 68
# img_array[0,0] = 9
# img_array[0,0] = 14
# img_array[0,1] = 100
# img_array[0,0] = 49
# img_array[0,0] = 41
# img_array[0,0] = 96
# img_array[0,0] = 15
# img_array[0,0] = 96
# img_array[0,0] = 83
# img_array[0,0] = 69
# img_array[0,0] = 17
# img_array[0,0] = 11
# img_array[0,0] = 47
# img_array[0,0] = 25
# img_array[0,0] = 12
# img_array[0,0] = 14
# img_array[0,0] = 58
# img_array[0,0] = 72
# img_array[0,0] = 1
# img_array[0,0] = 90
# img_array[0,0] = 66
# img_array[0,0] = 100
# img_array[0,0] = 1
# img_array[0,0] = 47
# img_array[0,0] = 0
# img_array[0,0] = 39
# img_array[0,0] = 16
# img_array[0,0] = 40
# img_array[0,0] = 19
# img_array[0,0] = 40
# img_array[0,0] = 96
# img_array[0,0] = 94
# img_array[0,0] = 80
# img_array[0,0] = 58
# img_array[0,0] = 60
# img_array[0,0] = 4
# img_array[0,0] = 51
# img_array[0,0] = 94
# img_array[0,0] = 92
# img_array[0,0] = 69
# img_array[0,0] = 10
# img_array[0,0] = 69
# img_array[0,0] = 1
# img_array[0,0] = 38
# img_array[0,0] = 91
# img_array[0,0] = 73
# img_array[0,0] = 93
# img_array[0,0] = 10
# img_array[0,0] = 37
# img_array[0,0] = 56
# img_array[0,1] = 87
# img_array[0,0] = 10
# img_array[0,0] = 54
# img_array[0,0] = 92
# img_array[0,0] = 76
# img_array[0,0] = 97
# img_array[0,0] = 37
# img_array[0,0] = 94
# img_array[0,0] = 44
# img_array[0,0] = 1
# img_array[0,0] = 72
# img_array[0,0] = 71
# img_array[0,0] = 30
# img_array[0,0] = 73
# img_array[0,0] = 87
# img_array[0,0] = 55
# img_array[0,0] = 0
# img_array[0,0] = 32
# img_array[0,0] = 33
# img_array[0,0] = 61
# img_array[0,0] = 12
# img_array[0,0] = 79
# img_array[0,0] = 73
# img_array[0,0] = 94
# img_array[0,0] = 52
# img_array[0,0] = 87
# img_array[0,1] = 97
# img_array[0,0] = 68
# img_array[0,0] = 76
# img_array[0,0] = 12
# img_array[0,0] = 75
# img_array[0,0] = 22
# img_array[0,0] = 69
# img_array[0,0] = 62
# img_array[0,0] = 56
# img_array[0,0] = 31
# img_array[0,0] = 95
# img_array[0,0] = 80
# img_array[0,0] = 50
# img_array[0,0] = 1
# img_array[0,0] = 35
# img_array[0,0] = 57
# img_array[0,0] = 83
# img_array[0,0] = 56
# img_array[0,0] = 1
# img_array[0,0] = 44
# img_array[0,0] = 4
# img_array[0,0] = 50
# img_array[0,0] = 100
# img_array[0,0] = 1
# img_array[0,0] = 37
# img_array[0,0] = 39
# img_array[0,0] = 27
# img_array[0,0] = 99
# img_array[0,0] = 1
# img_array[0,0] = 39
# img_array[0,0] = 77
# img_array[0,0] = 79
# img_array[0,0] = 87
# img_array[0,0] = 40
# img_array[0,0] = 59
# img_array[0,0] = 70
# img_array[0,1] = 99
# img_array[0,0] = 37
# img_array[0,1] = 75
# img_array[0,0] = 86
# img_array[0,0] = 99
# img_array[0,0] = 41
# img_array[0,0] = 76
# img_array[0,0] = 89
# img_array[0,0] = 17
# img_array[0,0] = 80
# img_array[0,0] = 28
# img_array[0,0] = 22
# img_array[0,0] = 32
# img_array[0,0] = 33
# img_array[0,1] = 100
# img_array[0,0] = 14
# img_array[0,0] = 65
# img_array[0,0] = 87
# img_array[0,0] = 91
# img_array[0,0] = 34
# img_array[0,0] = 68
# img_array[0,0] = 59
# img_array[0,0] = 25
# img_array[0,0] = 87
# img_array[0,0] = 8
# img_array[0,0] = 7
# img_array[0,0] = 7
# img_array[0,0] = 1
# img_array[0,0] = 73
# img_array[0,0] = 24
# img_array[0,0] = 2
# img_array[0,0] = 69
# img_array[0,0] = 27
# img_array[0,0] = 16
# img_array[0,0] = 85
# img_array[0,1] = 70
# img_array[0,0] = 80
# img_array[0,0] = 96
# img_array[0,0] = 55
# img_array[0,0] = 94
# img_array[0,0] = 83
# img_array[0,0] = 0
# img_array[0,0] = 40
# img_array[0,0] = 62
# img_array[0,0] = 17
# img_array[0,0] = 49
# img_array[0,0] = 54
# img_array[0,0] = 98
# img_array[0,0] = 37
# img_array[0,0] = 83
# img_array[0,0] = 28
# img_array[0,0] = 96
# img_array[0,0] = 37
# img_array[0,0] = 31
# img_array[0,0] = 79
# img_array[0,0] = 13
# img_array[0,0] = 43
# img_array[0,0] = 46
# img_array[0,0] = 29
# img_array[0,0] = 80
# img_array[0,0] = 89
# img_array[0,0] = 1
# img_array[0,0] = 31
# img_array[0,0] = 91
# img_array[0,0] = 1
# img_array[0,0] = 98
# img_array[0,0] = 20
# img_array[0,0] = 53
# img_array[0,0] = 76
# img_array[0,0] = 16
# img_array[0,0] = 34
# img_array[0,0] = 18
# img_array[0,0] = 11
# img_array[0,0] = 78
# img_array[0,1] = 84
# img_array[0,0] = 93
# img_array[0,0] = 6
# img_array[0,0] = 58
# img_array[0,0] = 6
# img_array[0,0] = 72
# img_array[0,0] = 99
# img_array[0,0] = 75
# img_array[0,0] = 34
# img_array[0,0] = 54
# img_array[0,0] = 75
# img_array[0,0] = 1
# img_array[0,0] = 53
# img_array[0,0] = 29
# img_array[0,1] = 84
# img_array[0,0] = 1
# img_array[0,0] = 74
# img_array[0,0] = 36
# img_array[0,1] = 99
# img_array[0,0] = 40
# img_array[0,0] = 36
# img_array[0,0] = 80
# img_array[0,0] = 0
# img_array[0,1] = 55
# img_array[0,0] = 29
# img_array[0,0] = 69
# img_array[0,0] = 41
# img_array[0,0] = 4
# img_array[0,0] = 97
# img_array[0,0] = 30
# img_array[0,0] = 49
# img_array[0,0] = 72
# img_array[0,0] = 75
# img_array[0,0] = 58
# img_array[0,0] = 91
# img_array[0,0] = 28
# img_array[0,0] = 48
# img_array[0,0] = 12
# img_array[0,0] = 92
# img_array[0,0] = 8
# img_array[0,0] = 39
# img_array[0,0] = 51
# img_array[0,0] = 82
# img_array[0,0] = 84
# img_array[0,0] = 40
# img_array[0,0] = 13
# img_array[0,0] = 96
# img_array[0,0] = 1
# img_array[0,0] = 28
# img_array[0,0] = 9
# img_array[0,0] = 65
# img_array[0,0] = 79
# img_array[0,0] = 8
# img_array[0,0] = 64
# img_array[0,0] = 89
# img_array[0,0] = 55
# img_array[0,0] = 95
# img_array[0,0] = 21
# img_array[0,0] = 2
# img_array[0,0] = 67
# img_array[0,0] = 27
# img_array[0,0] = 81
# img_array[0,0] = 1
# img_array[0,0] = 49
# img_array[0,0] = 100
# img_array[0,0] = 99
# img_array[0,0] = 7
# img_array[0,0] = 50
# img_array[0,0] = 39
# img_array[0,0] = 1
# img_array[0,0] = 77
# img_array[0,0] = 42
# img_array[0,0] = 89
# img_array[0,0] = 1
# img_array[0,0] = 17
# img_array[0,0] = 35
# img_array[0,0] = 93
# img_array[0,0] = 4
# img_array[0,0] = 29
# img_array[0,0] = 38
# img_array[0,0] = 24
# img_array[0,1] = 87
# img_array[0,0] = 86
# img_array[0,0] = 48
# img_array[0,0] = 88
# img_array[0,0] = 14
# img_array[0,0] = 43
# img_array[0,0] = 75
# img_array[0,0] = 64
# img_array[0,0] = 46
# img_array[0,0] = 82
# img_array[0,0] = 8
# img_array[0,0] = 96
# img_array[0,0] = 41
# img_array[0,1] = 58
# img_array[0,0] = 78
# img_array[0,0] = 87
# img_array[0,0] = 27
# img_array[0,0] = 91
# img_array[0,0] = 62
# img_array[0,0] = 80
# img_array[0,0] = 41
# img_array[0,0] = 18
# img_array[0,0] = 93
# img_array[0,0] = 74
# img_array[0,0] = 100
# img_array[0,0] = 93
# img_array[0,0] = 0
# img_array[0,0] = 70
# img_array[0,0] = 9
# img_array[0,0] = 44
# img_array[0,0] = 1
# img_array[0,0] = 89
# img_array[0,0] = 49
# img_array[0,0] = 47
# img_array[0,0] = 30
# img_array[0,0] = 0
# img_array[0,0] = 75
# img_array[0,0] = 50
# img_array[0,1] = 99
# img_array[0,0] = 31
# img_array[0,0] = 35
# img_array[0,0] = 1
# img_array[0,0] = 14
# img_array[0,0] = 66
# img_array[0,1] = 67
# img_array[0,0] = 89
# img_array[0,0] = 68
# img_array[0,0] = 77
# img_array[0,0] = 33
# img_array[0,0] = 73
# img_array[0,0] = 70
# img_array[0,0] = 23
# img_array[0,0] = 1
# img_array[0,0] = 30
# img_array[0,0] = 21
# img_array[0,0] = 65
# img_array[0,0] = 90
# img_array[0,0] = 4
# img_array[0,0] = 100
# img_array[0,0] = 53
# img_array[0,0] = 63
# img_array[0,0] = 42
# img_array[0,1] = 98
# img_array[0,0] = 40
# img_array[0,0] = 75
# img_array[0,0] = 87
# img_array[0,0] = 1
# img_array[0,0] = 45
# img_array[0,0] = 92
# img_array[0,0] = 58
# img_array[0,0] = 1
# img_array[0,0] = 81
# img_array[0,0] = 49
# img_array[0,0] = 72
# img_array[0,0] = 84
# img_array[0,0] = 92
# img_array[0,0] = 79
# img_array[0,0] = 84
# img_array[0,0] = 99
# img_array[0,1] = 80
# img_array[0,0] = 74
# img_array[0,0] = 1
# img_array[0,0] = 43
# img_array[0,0] = 67
# img_array[0,0] = 20
# img_array[0,0] = 76
# img_array[0,0] = 3
# img_array[0,0] = 56
# img_array[0,0] = 44
# img_array[0,0] = 81
# img_array[0,0] = 79
# img_array[0,0] = 40
# img_array[0,0] = 0
# img_array[0,0] = 3
# img_array[0,0] = 65
# img_array[0,0] = 8
# img_array[0,0] = 98
# img_array[0,0] = 20
# img_array[0,0] = 5
# img_array[0,0] = 90
# img_array[0,0] = 71
# img_array[0,0] = 95
# img_array[0,0] = 28
# img_array[0,0] = 83
# img_array[0,0] = 60
# img_array[0,0] = 1
# img_array[0,0] = 1
# img_array[0,0] = 71
# img_array[0,0] = 3
# img_array[0,0] = 52
# img_array[0,0] = 55
# img_array[0,0] = 28
# img_array[0,0] = 55
# img_array[0,0] = 41
# img_array[0,0] = 51
# img_array[0,0] = 90
# img_array[0,0] = 62
# img_array[0,0] = 71
# img_array[0,0] = 16
# img_array[0,0] = 0
# img_array[0,0] = 61
# img_array[0,0] = 94
# img_array[0,1] = 88
# img_array[0,0] = 29
# img_array[0,0] = 38
# img_array[0,0] = 83
# img_array[0,0] = 84
# img_array[0,0] = 44
# img_array[0,0] = 67
# img_array[0,0] = 4
# img_array[0,0] = 92
# img_array[0,0] = 56
# img_array[0,0] = 16
# img_array[0,0] = 24
# img_array[0,0] = 32
# img_array[0,0] = 40
# img_array[0,0] = 41
# img_array[0,0] = 89
# img_array[0,0] = 84
# img_array[0,0] = 55
# img_array[0,0] = 14
# img_array[0,0] = 36
# img_array[0,0] = 15
# img_array[0,1] = 97
# img_array[0,1] = 93
# img_array[0,0] = 24
# img_array[0,0] = 1
# img_array[0,0] = 59
# img_array[0,0] = 36
# img_array[0,0] = 81
# img_array[0,0] = 75
# img_array[0,0] = 87
# img_array[0,0] = 75
# img_array[0,0] = 17
# img_array[0,0] = 76
# img_array[0,0] = 53
# img_array[0,0] = 61
# img_array[0,0] = 47
# img_array[0,0] = 80
# img_array[0,0] = 12
# img_array[0,0] = 17
# img_array[0,0] = 40
# img_array[0,0] = 29
# img_array[0,0] = 25
# img_array[0,0] = 17
# img_array[0,0] = 1
# img_array[0,0] = 48
# img_array[0,0] = 13
# img_array[0,0] = 64
# img_array[0,0] = 84
# img_array[0,0] = 19
# img_array[0,0] = 9
# img_array[0,0] = 77
# img_array[0,0] = 38
# img_array[0,0] = 62
# img_array[0,0] = 42
# img_array[0,0] = 24
# img_array[0,0] = 78
# img_array[0,0] = 54
# img_array[0,0] = 78
# img_array[0,0] = 92
# img_array[0,0] = 52
# img_array[0,0] = 46
# img_array[0,0] = 7
# img_array[0,0] = 76
# img_array[0,0] = 21
# img_array[0,0] = 81
# img_array[0,0] = 38
# img_array[0,0] = 11
# img_array[0,0] = 8
# img_array[0,0] = 9
# img_array[0,0] = 30
# img_array[0,0] = 95
# img_array[0,0] = 41
# img_array[0,0] = 53
# img_array[0,0] = 85
# img_array[0,0] = 90
# img_array[0,0] = 0
# img_array[0,0] = 51
# img_array[0,0] = 1
# img_array[0,0] = 73
# img_array[0,0] = 36
# img_array[0,0] = 1
# img_array[0,0] = 77
# img_array[0,0] = 33
# img_array[0,0] = 4
# img_array[0,0] = 98
# img_array[0,0] = 80
# img_array[0,0] = 7
# img_array[0,0] = 40
# img_array[0,0] = 27
# img_array[0,0] = 56
# img_array[0,0] = 50
# img_array[0,0] = 41
# img_array[0,0] = 84
# img_array[0,0] = 75
# img_array[0,0] = 15
# img_array[0,0] = 35
# img_array[0,0] = 99
# img_array[0,0] = 22
# img_array[0,0] = 88
# img_array[0,0] = 70
# img_array[0,0] = 8
# img_array[0,0] = 76
# img_array[0,0] = 79
# img_array[0,0] = 3
# img_array[0,0] = 72
# img_array[0,0] = 88
# img_array[0,0] = 54
# img_array[0,0] = 38
# img_array[0,0] = 8
# img_array[0,0] = 70
# img_array[0,0] = 53
# img_array[0,0] = 84
# img_array[0,0] = 15
# img_array[0,0] = 14
# img_array[0,0] = 55
# img_array[0,0] = 44
# img_array[0,0] = 83
# img_array[0,0] = 71
# img_array[0,0] = 1
# img_array[0,0] = 94
# img_array[0,0] = 1
# img_array[0,0] = 62
# img_array[0,0] = 51
# img_array[0,0] = 61
# img_array[0,0] = 58
# img_array[0,0] = 59
# img_array[0,1] = 99
# img_array[0,0] = 70
# img_array[0,0] = 40
# img_array[0,0] = 81
# img_array[0,0] = 8
# img_array[0,0] = 62
# img_array[0,0] = 77
# img_array[0,0] = 82
# img_array[0,0] = 19
# img_array[0,0] = 24
# img_array[0,0] = 85
# img_array[0,0] = 79
# img_array[0,0] = 29
# img_array[0,0] = 58
# img_array[0,0] = 7
# img_array[0,0] = 68
# img_array[0,0] = 91
# img_array[0,0] = 97
# img_array[0,0] = 95
# img_array[0,0] = 84
# img_array[0,0] = 0
# img_array[0,0] = 49
# img_array[0,0] = 85
# img_array[0,0] = 30
# img_array[0,0] = 1
# img_array[0,0] = 90
# img_array[0,0] = 1
# img_array[0,0] = 7
# img_array[0,0] = 78
# img_array[0,0] = 53
# img_array[0,0] = 67
# img_array[0,0] = 43
# img_array[0,0] = 57
# img_array[0,0] = 4
# img_array[0,1] = 95
# img_array[0,0] = 65
# img_array[0,0] = 99
# img_array[0,0] = 74
# img_array[0,0] = 23
# img_array[0,0] = 78
# img_array[0,0] = 1
# img_array[0,0] = 89
# img_array[0,0] = 35
# img_array[0,1] = 68
# img_array[0,0] = 87
# img_array[0,0] = 82
# img_array[0,0] = 89
# img_array[0,0] = 8
# img_array[0,0] = 82
# img_array[0,0] = 58
# img_array[0,0] = 41
# img_array[0,0] = 15
# img_array[0,0] = 1
# img_array[0,1] = 100
# img_array[0,0] = 76
# img_array[0,1] = 89
# img_array[0,0] = 49
# img_array[0,0] = 39
# img_array[0,0] = 81
# img_array[0,0] = 26
# img_array[0,0] = 63
# img_array[0,0] = 83
# img_array[0,0] = 4
# img_array[0,0] = 74
# img_array[0,0] = 62
# img_array[0,0] = 48
# img_array[0,0] = 52
# img_array[0,0] = 20
# img_array[0,0] = 71
# img_array[0,0] = 34
# img_array[0,0] = 41
# img_array[0,0] = 73
# img_array[0,0] = 49
# img_array[0,0] = 30
# img_array[0,0] = 54
# img_array[0,0] = 11
# img_array[0,0] = 81
# img_array[0,0] = 3
# img_array[0,0] = 60
# img_array[0,0] = 99
# img_array[0,1] = 75
# img_array[0,0] = 1
# img_array[0,0] = 74
# img_array[0,0] = 94
# img_array[0,0] = 34
# img_array[0,0] = 80
# img_array[0,0] = 58
# img_array[0,0] = 72
# img_array[0,0] = 73
# img_array[0,0] = 18
# img_array[0,0] = 56
# img_array[0,0] = 51
# img_array[0,0] = 28
# img_array[0,0] = 90
# img_array[0,0] = 1
# img_array[0,0] = 2
# img_array[0,0] = 23
# img_array[0,0] = 42
# img_array[0,0] = 38
# img_array[0,0] = 1
# img_array[0,0] = 92
# img_array[0,0] = 21
# img_array[0,0] = 7
# img_array[0,0] = 3
# img_array[0,0] = 71
# img_array[0,1] = 87
# img_array[0,0] = 10
# img_array[0,0] = 63
# img_array[0,0] = 98
# img_array[0,0] = 50
# img_array[0,0] = 60
# img_array[0,0] = 91
# img_array[0,0] = 68
# img_array[0,0] = 34
# img_array[0,0] = 43
# img_array[0,0] = 1
# img_array[0,0] = 58
# img_array[0,1] = 98
# img_array[0,0] = 31
# img_array[0,0] = 38
# img_array[0,0] = 52
# img_array[0,0] = 78
# img_array[0,0] = 18
# img_array[0,0] = 77
# img_array[0,0] = 82
# img_array[0,0] = 94
# img_array[0,0] = 59
# img_array[0,0] = 48
# img_array[0,0] = 53
# img_array[0,0] = 36
# img_array[0,0] = 61
# img_array[0,0] = 96
# img_array[0,0] = 88
# img_array[0,0] = 47
# img_array[0,0] = 96
# img_array[0,0] = 91
# img_array[0,0] = 63
# img_array[0,0] = 20
# img_array[0,0] = 64
# img_array[0,0] = 88
# img_array[0,0] = 4
# img_array[0,0] = 50
# img_array[0,0] = 7
# img_array[0,0] = 81
# img_array[0,0] = 80
# img_array[0,0] = 81
# img_array[0,0] = 88
# img_array[0,0] = 58
# img_array[0,1] = 92
# img_array[0,0] = 89
# img_array[0,0] = 86
# img_array[0,0] = 1
# img_array[0,0] = 67
# img_array[0,0] = 51
# img_array[0,0] = 92
# img_array[0,0] = 49
# img_array[0,0] = 29
# img_array[0,0] = 33
# img_array[0,0] = 47
# img_array[0,0] = 55
# img_array[0,0] = 54
# img_array[0,0] = 48
# img_array[0,0] = 57
# img_array[0,0] = 41
# img_array[0,1] = 85
# img_array[0,0] = 92
# img_array[0,0] = 32
# img_array[0,0] = 17
# img_array[0,0] = 6
# img_array[0,0] = 6
# img_array[0,0] = 54
# img_array[0,0] = 64
# img_array[0,0] = 84
# img_array[0,0] = 17
# img_array[0,0] = 84
# img_array[0,0] = 95
# img_array[0,0] = 15
# img_array[0,0] = 40
# img_array[0,0] = 17
# img_array[0,0] = 7
# img_array[0,0] = 97
# img_array[0,0] = 57
# img_array[0,0] = 90
# img_array[0,0] = 85
# img_array[0,0] = 85
# img_array[0,0] = 1
# img_array[0,0] = 42
# img_array[0,0] = 88
# img_array[0,1] = 96
# vecRC.shape = (6536, 2)       vecRC.size = 13072       len(vecRC) = 6536       len(vecRC[:,0]) = 6536       len(vecRC[:,1]) = 6536
# Number of pictures that was too small: 4360

# %%
# Kontrollera att det är rimligt antal pxl-värden på första 15 bilderna
[vecRC[:10,0], vecRC[:10,1]]


# max och min värden på pxl antal för alla aktuella bilder samt formfaktor
print(f"{max(vecRC[:,0]) = }       {min(vecRC[:,0]) = }       {max(vecRC[:,1]) = }       {min(vecRC[:,1]) = }")
print(f"{max(vecRC[:,0]/vecRC[:,1]) = }       {min(vecRC[:,0]/vecRC[:,1]) = } ")
print(f"{max(vecRC[:,1]/vecRC[:,0]) = }       {min(vecRC[:,1]/vecRC[:,0]) = } ")


NumOfBins = 20
yx_mat = plt.hist( (vecRC[:,1]/vecRC[:,0]), bins=NumOfBins)

mv = (vecRC[:,1]/vecRC[:,0]).mean()
sv = (vecRC[:,1]/vecRC[:,0]).std()
ymin = min(yx_mat[0])
ymax = max(yx_mat[0])
y10part = (ymax-ymin)/10

plt.plot([mv, mv], [ymin, ymax], 'r--')
plt.plot([mv-sv, mv-sv], [ymin, ymax], 'g--')
plt.plot([mv+sv, mv+sv], [ymin, ymax], 'g--')
plt.plot([mv-2*sv, mv-2*sv], [ymin, ymax], 'y--')
plt.plot([mv+2*sv, mv+2*sv], [ymin, ymax], 'y--')
plt.title(f"Quota of picture-axis pxl-lengths, tot: {len(vecRC)} pictures")
plt.xlabel(f"Horiz length $\\div$ Vert length, {NumOfBins} bars")
plt.ylabel("population")

plt.text(mv-2*sv, ymax-2*y10part, (r'$\bar{x}$' + '$ \\minus 2\\sigma$'), size=12)
plt.text(mv+2*sv, ymax-2*y10part, (r'$\bar{x}$' + '$ \\plus 2\\sigma$'), size=12)

plt.text(mv-sv, ymax-1.2*y10part, (r'$\bar{x}$' + '$ \\minus \\sigma$'), size=12)
plt.text(mv+sv, ymax-1.2*y10part, (r'$\bar{x}$' + '$ \\plus \\sigma$'), size=12)

plt.text(mv, ymax-y10part, r'$\bar{x}$', size=13)
# Out:
# max(vecRC[:,0]) = 3000       min(vecRC[:,0]) = 75       max(vecRC[:,1]) = 4512       min(vecRC[:,1]) = 107
# max(vecRC[:,0]/vecRC[:,1]) = 2.7522935779816513       min(vecRC[:,0]/vecRC[:,1]) = 0.30666666666666664
# max(vecRC[:,1]/vecRC[:,0]) = 3.260869565217391       min(vecRC[:,1]/vecRC[:,0]) = 0.36333333333333334
# Text(1.1322362542864863, 5446.8, '$\\bar{x}$')

# %%
#
# SLUTSATS :: minsta bildsida: 149 pxl  -->> kan utföra metodutveckling på bilder med IMG_SIZE = 100
#          :: Ska ändra storlek hos bilderna så att all erhåller exakt samma storlek i bredd & höjd
#             transformerar X-/Y-antalet pixlar till IMG_SIZE --> kvadratisk form
#             transformationen kommer leda till irreparabel förändring i bredd-/höjdförhållandet
#             förhoppningsvis skall denna transformation inte förstöra möjlighet till stark AI-modell
#

# %%
# -- obs. bara test här, låt IMG_SIZE bli definierad vid start
# IMG_SIZE = 100

training_data = []

def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)                                          # path till katter och hundar
        class_num = CATEGORIES.index(category)                                          # Aktuell djur-nuffra
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)   # Behåller endast gråskalevärde på bildinnehåll
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))                 # Komprimerande transformering av bild
                training_data.append([new_array, class_num])                            # [  [bild-nuffror], [djur-nuffra]  ]
            except Exception as e:
                print(e)
                pass


create_training_data()

# %%
print(f"  {len(training_data)  =  }   ")
# Out:
#   len(training_data)  =  10896

# %%
# Skyffla runt datat så att katter & hundar beblandas i tensorn

import random
random.shuffle(training_data)

# %%
# Kontrollera hur "categorie" har blandats hos de tio första - katt '0', hund '1'

for sample in training_data[:10]:
    print(sample[1])

# training_data
# Out:
# 1
# 1
# 0
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %%
# Input X, output y

X = []
y = []

# %%
# Skapar listor med numeriska värde på in-/utdata, som används att skapa numpy tensorerna
# Tensorerna agerar container för indatat och utdatat, samt erhåller trevliga numeriska funktioner

for features,label in training_data:
    X.append(features)
    y.append(label)

# Båda tensorerna behöver samma format för senare behandling
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
y = np.array(y).reshape((len(y), 1))

# %%
# Flusha dataström till disk, att representera in-/utdata

import pickle

TxT_inp_fileN = DATADIR_MOD + "X.pickle"
TxT_out_fileN = DATADIR_MOD + "y.pickle"

print(TxT_inp_fileN)
print(TxT_out_fileN)

pickle_out = open(TxT_inp_fileN,"wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open(TxT_out_fileN,"wb")
pickle.dump(y, pickle_out)
pickle_out.close()
# Out:
# C:\LTH_data\photo\PythUtbPic\SKARP\X.pickle
# C:\LTH_data\photo\PythUtbPic\SKARP\y.pickle

# %%
print(f"{X.shape = }           {X.size = }           {len(X) = }       ")
print(f"{y.shape = }           {y.size = }           {len(y) = }       ")
# Out:
# X.shape = (10896, 100, 100, 1)           X.size = 108960000           len(X) = 10896
# y.shape = (10896, 1)           y.size = 10896           len(y) = 10896

# %%
print(f"{type(X) = }       {type(y) = }    ")
# Out:
# type(X) = <class 'numpy.ndarray'>       type(y) = <class 'numpy.ndarray'>

# %%
# Testa att läsa

pickle_in = open(TxT_inp_fileN,"rb")
X = pickle.load(pickle_in)
pickle_in.close()

# %%
X.shape
# Out:
# (10896, 100, 100, 1)

# %%
# y

# %%
print(f"{X.shape = }       {X.size = }       {len(X) = }       {len(y) = }       ")
# Out:
# X.shape = (10896, 100, 100, 1)       X.size = 108960000       len(X) = 10896       len(y) = 10896

# %%
print(f"{type(X) = }       {type(y) = }    ")
# Out:
# type(X) = <class 'numpy.ndarray'>       type(y) = <class 'numpy.ndarray'>
