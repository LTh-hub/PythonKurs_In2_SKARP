# %%
# 
# Behöver få reda på vad modellen ger för svar i uppskattning från foto
# Den här filen har tagits fram för att kunna testa given CNN modell på alla foton i en katalog
# På så vis kan en omfattande analys genomföras angående hur aktuell modell separerar katter och hundar
#
# Ange lämplig modell och peka ut en katalog med rätt djur
#

# %%
import numpy as np                   # för array matrix operationer
import matplotlib.pyplot as plt      # för att visualisera data
import os                            # för att iterera genom bibliotek med bilder
import cv2                           # för att uföra image operationer
import tensorflow as tf

# %%
IMG_SIZE = 75

DATADIR = "C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\"      # path till katalog med djurbilder
DATADIR_MOD = DATADIR                                     # path till sparad modell

TxT_MODEL_4_fName = DATADIR_MOD + 'steg4_256x3x5-CNN.keras' # Steg 4 anpassad modell
TxT_MODEL_5_fName = DATADIR_MOD + 'steg5-CNN.keras'         # Steg 5 anpassad modell

#CATEGORIES = ["500pCats", "500pDogs"]
CATEGORIES = ["CatTest", "DogTest"]
#CATEGORIES = ["Cat", "Dog"]

# %%
def print_some_pic_values(path, category, img):
    print("_"*50)
    print(f"{path = }")
    print(f"{category = }")
    print(f"{img = }")

# %%
# Hämta upp aktuell modell

#model = tf.keras.models.load_model(TxT_MODEL_4_fName)
model = tf.keras.models.load_model(TxT_MODEL_5_fName)

# %%
# returnerar AI-modellens classificerade svar

def print_the_response(from_prediction):
    print(f"               {from_prediction[0][0]   =  }")
    print(f"         {round(from_prediction[0][0])  =  }")
    print(f"           {int(from_prediction[0][0])  =  }")
    print(f"{CATEGORIES[int(from_prediction[0][0])] =  }")
    return CATEGORIES[int(from_prediction[0][0])]

# %%
def prepare_the_image(filepath, OK=True):
    print(f"{filepath = }")
    #IMG_SIZE = 100
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    if OK:
        plt.subplot(1,2,1)
        plt.imshow(img_array, cmap="grey")
        plt.title(f"{img_array.size = }")
        plt.subplot(1,2,2)
        plt.imshow(new_array, cmap="grey")
        plt.title(f"{new_array.size = }")
        plt.show()
    
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
# Ska titta på ett första foto


def calculate_the_pred_vec(DATADIR, CATEGOR_Num=0, ShowPic=False, ShowTxT=False):
    #IMG_SIZE = 100
    vec_of_predictions = []
    category = CATEGORIES[CATEGOR_Num]
    print(category)
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        if ShowTxT:
            print_some_pic_values(path, category, img)
        
        img_file_path = os.path.join(path, img)
        pic_array = prepare_the_image(img_file_path, OK=ShowPic)
    
        normed_array = pic_array/255.0              # Normera gråskallenivå, (0,255) transformeras till (0,1), utan medlevärdesförskjutning
        prediction = model.predict([normed_array])
        vec_of_predictions.append(prediction[0][0])
        
    return vec_of_predictions

# %%
def make_a_sweet_histogram(vec_of_predictions, NumOfBins=25):
    yx_mat = plt.hist( vec_of_predictions, bins=NumOfBins)
    
    mv = np.mean(vec_of_predictions)
    sv = np.std(vec_of_predictions)
    ymin = np.min(yx_mat[0])
    ymax = np.max(yx_mat[0])
    y10part = (ymax-ymin)/10
    
    plt.plot([mv, mv], [ymin, ymax], 'r--')
    plt.plot([mv-sv, mv-sv], [ymin, ymax], 'g--')
    plt.plot([mv+sv, mv+sv], [ymin, ymax], 'g--')
    plt.plot([mv-2*sv, mv-2*sv], [ymin, ymax], 'y--')
    plt.plot([mv+2*sv, mv+2*sv], [ymin, ymax], 'y--')
    plt.title(f"Total number of pictures: {len(vec_of_predictions)}")
    plt.xlabel(f"float value part of prediction")
    plt.ylabel("population")
    plt.text(mv-2*sv, ymax-2*y10part, (r'$\bar{x}$' + '$ \\minus 2\\sigma$'), size=12)
    plt.text(mv+2*sv, ymax-2*y10part, (r'$\bar{x}$' + '$ \\plus 2\\sigma$'), size=12)
    plt.text(mv-sv, ymax-1.2*y10part, (r'$\bar{x}$' + '$ \\minus \\sigma$'), size=12)
    plt.text(mv+sv, ymax-1.2*y10part, (r'$\bar{x}$' + '$ \\plus \\sigma$'), size=12)
    plt.text(mv, ymax-y10part, r'$\bar{x}$', size=13)

# %%
#
# Funktionen här beaktar två ytterligheter, stora och små kopplat till gränserna [0...1]
# stora 'big' är antalet prediktioner >= 0.5
# små 'small' är antalet prediktioner < 0.5
# above är lista med prediktioner <= 0.5
# under är lista med prediktioner > 0.5
# Ser på katt-värde tillörande P_katt<0.5 och p.s.s P_hund >= 0.5
#

def separate_05_as_the_middle(vec_of_predictions, ShowValues=False):
    big = 0
    small = 0
    above = []
    under = []
    for i in vec_of_predictions:
        if i>=0.5:
            big += 1
            above.append(i)
        else:
            small += 1
            under.append(i)

    if ShowValues:
        print(f"Proportion above 0.5: {round(100*big/len(vec_of_predictions))/100}")
        print(f"Proportion under 0.5: {round(100*small/len(vec_of_predictions))/100}")
    #print(f"{len(big)  =  }")
    #print(f"{len(big)/len(vec_of_predictions)  =  }")
    ans = [big, small, above, under]
    return ans

# %%
def print_some_sweet_values_from_the_prediction(vec_of_predictions, ll):
    print(f"{len(vec_of_predictions)  =  }")
    print(f"{np.mean(vec_of_predictions)  =  }")
    print(f"{round(np.mean(vec_of_predictions))  =  }")
    print(f"{CATEGORIES[round(np.mean(vec_of_predictions))]  =  }\n")
    c_value = ll[1]/(ll[0]+ll[1])
    d_value = ll[0]/(ll[0]+ll[1])
    print(f"Calculated probability as a CAT pictures: {c_value}\t-->>\t{round(1000*c_value)/10} %")
    print(f"Calculated probability as a DOG pictures: {d_value}\t-->>\t{round(1000*d_value)/10} %")
    print(f"           If pictures of Cats --> RMSEC: {np.round(1000*np.sqrt(ll[0]/len(vec_of_predictions)))/1000}")
    print(f"           If pictures of Dogs --> RMSEC: {np.round(1000*np.sqrt(ll[1]/len(vec_of_predictions)))/1000}")

# %%
#
# Start med att analysera resultat från katalog med endast katter

vec_of_CAT_predictions = calculate_the_pred_vec(DATADIR)
# Out:
# CatTest
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\CatTest\\cat2272.jpg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# C:\Users\larth\anaconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: input_layer
# Received: inputs=('Tensor(shape=(1, 75, 75, 1))',)
#   warnings.warn(msg)
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\CatTest\\cat2273.jpg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\CatTest\\cat2274.jpg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\CatTest\\cat2275.jpg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\CatTest\\cat2276.jpg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\CatTest\\cat2277.jpg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# ...

# %%
ll = separate_05_as_the_middle(vec_of_CAT_predictions, ShowValues=True)

print_some_sweet_values_from_the_prediction(vec_of_CAT_predictions, ll)

make_a_sweet_histogram(vec_of_CAT_predictions)
# Out:
# Proportion above 0.5: 0.06
# Proportion under 0.5: 0.94
# len(vec_of_predictions)  =  400
# np.mean(vec_of_predictions)  =  0.07077941
# round(np.mean(vec_of_predictions))  =  0
# CATEGORIES[round(np.mean(vec_of_predictions))]  =  'CatTest'
#
# Calculated probability of CAT pictures: 0.945	-->>	94.5 %
# Calculated probability of DOG pictures: 0.055	-->>	5.5 %
#          If pictures of Cats --> RMSEC: 0.235
#          If pictures of Dogs --> RMSEC: 0.972

# %%
#
# Fortsätter med att analysera resultat från katalog med endast hundar

vec_of_Dog_predictions = calculate_the_pred_vec(DATADIR, CATEGOR_Num=1)
# Out:
# DogTest
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\DogTest\\OIP--EJV-0S_RAhDQbtUA8HhoAHaGi.jpeg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\DogTest\\OIP--GlCH31Wry6Uj4tAHTnIUwHaJv.jpeg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\DogTest\\OIP--GnTjiWNoY2Djyb3v7WXAgHaE7.jpeg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\DogTest\\OIP--hIXMAfOrmjSfDzjHHoZmwHaFj.jpeg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\DogTest\\OIP--HjjWS524SecIyPDEh8GNgHaJ4.jpeg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\DogTest\\OIP--HP-Jp3xDbJcfnayqlP7GwHaE7.jpeg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# filepath = 'C:\\LTH_data\\photo\\PythUtbPic\\SKARP\\DogTest\\OIP--hrVyxBHfXGXIpLKB_ld2AHaEK.jpeg'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# ...

# %%
ll = separate_05_as_the_middle(vec_of_Dog_predictions, ShowValues=True)

print_some_sweet_values_from_the_prediction(vec_of_Dog_predictions, ll)

make_a_sweet_histogram(vec_of_Dog_predictions)
# Out:
# Proportion above 0.5: 0.84
# Proportion under 0.5: 0.16
# len(vec_of_predictions)  =  480
# np.mean(vec_of_predictions)  =  0.7228882
# round(np.mean(vec_of_predictions))  =  1
# CATEGORIES[round(np.mean(vec_of_predictions))]  =  'DogTest'
#
# Calculated probability of CAT pictures: 0.16458333333333333	-->>	16.5 %
# Calculated probability of DOG pictures: 0.8354166666666667	-->>	83.5 %
#          If pictures of Cats --> RMSEC: 0.914
#          If pictures of Dogs --> RMSEC: 0.406
